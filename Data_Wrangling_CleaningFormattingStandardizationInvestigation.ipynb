# %% [markdown]
# # <center>Data Wrangling: Cleaning, Formatting, Standardization, and Investigation - Stacey Sandy</center>
#
# This week you will be retrieving and cleansing data from a survey generated by the National Center for Immunization and Respiratory Diseases about National Immunizations in Children. In completing this assignment, you will be able to combine topics discussed in several of our prior <i>From The Experts</i> (FTE)s.
#
# File needed to complete this assignment are located in the data_5 folder:
# * NISPUF14_CODEBOOK.PDF
# * nispuf14.dat
#
# Assignment Requirements:
# * Retrieve all of the data within nispuf14.dat and store it in a more <i> accessible format</i>
# * <i> Accessible format </i> can be any of the following:
#     - csv file
#     - json file
#     - relational database
# * For this assignment, feel free to use a dataframe for intermediate steps.
#
# <hr>

# %% [markdown]
# ### What's in these two files?
# I'm glad you asked that! And to be honest, you probably are not going to like the answer.
#
# NISPUF14_CODEBOOK.PDF is a PDF that contains a description of the format for the data in nispuf14.dat. In other words, the PDF tells you how to read the data in nispuf14.dat.
#
# Why would we need a PDF to tell us how to read our data?  Well, this data file is stored in a positional format. This means that both the value and relative position of each character provides meaning within the dataset.

# %% [markdown]
# Here's what the data in nispuf14.dat looks like.
# <img align="left" style="padding-right:10px;" src="figures_5/positional_data.jpeg" width = 800><br>

# %% [markdown]
# Ugly? Yes! And very much so. However, data in this format is not all that uncommon. Mainframe computers operate on positional formating.
#
# Q - Who still uses mainframe computers?<br>
# A - Mainframes are more prevalent than you'd think. Any industry that has a large volume of daily mathematical calculations to do, most likely use a mainframe computer as part of their normal operations. For example, the banking industry. Certainly, the website and customer-facing applications are not run on a mainframe computer, but the nightly accounting processes probably are.
#
# The following article walks through the history of the mainframe computer and how it has evolved over the years.
# https://www.thocp.net/hardware/mainframe.htm
#
# <hr>

# %% [markdown]
# ### How are we supposed to read that?
# This is where NISPUF14_CODEBOOK.PDF comes into the picture. Section 1 of the PDF contains the description of the positional formatting information for each data field. Here's how it works!
#
# As an example, let's say that our data file looked like this:<br>
# CAT  FLUFFY410<br>
# DOG  FIDO  522<br>
# BIRD CHIRP 2 1<br>
#
# At a glance, we can determine that each line contains information about animals. We can see a field representing an animal_type and perhaps an animal_name.  However, we have little to no information about what the numerics at the end of each line mean. Or even how many fields the numeric group is representing. The last line is leading us to believe that there might be more than one field represented, but we are not confident at this point.

# %% [markdown]
# ### Does this come with a 'Magical Decoder Ring'?
# Short of an actual magical ring, I'd settle for a description of each field and their relative position in the line.  It would be even better if the description was written down for future reference.
#
# Let's look at the above animal dataset in conjunction with the  following description:<br>
# Type 1 5<br>
# Name 6 11<br>
# Age 12 12<br>
# Weight 13 14<br>
#
# Aaahhhhh! Now everything is starting to come together!!! We can now confirm that the first field is indeed animal_type, and the second is animal_name. However, we now know that the numeric grouping is really two fields, animal_age and animal_weight. We can also see that animal_age is a single digit, and animal_weight is a 2-digit numeric. We are also able to determine at this point that the animal_name on the first line is actually 'FLUFFY' and not 'FLUFFY410'.
#
# Time to add a little code to this example.
#
# <hr>

# %%
# Load the sample data into a list
animal_data = ['CAT  FLUFFY410', 'DOG  FIDO  522', 'BIRD CHIRP 2 1' ]

# processing each animal_data line
for  line in animal_data:
    animal_type = line[0:5]
    animal_name = line[5:11]
    age = line[11]
    weight = line[12:14]
    
    print(f'{animal_name} is a {animal_type} that is {age} years old and weights {weight} pound(s)')

# %% [markdown]
# Hopefully, things are looking less scary at this point?
#
# Retrieving data from a positionally formatted file is just a matter of chunking the larger string up into smaller pieces. The trick is in determining where to make those chunks.
#
# The key to all this is the 'magical decoder' description because there are no other clues in the file itself. Unlike a csv type file, positional formatted files don't have a delimited to help identify individual data elements.
#
# That being said, positional formats do account for every character within a row.  Meaning that even unused characters are given a value. In our example above, a blank  character(' ') was used to fill unused characters. The value used to represent unused characters can literally be anything. For example, if '-' was used instead of a ' ' our sample data would have looked like:
#
# CAT--FLUFFY410<br>
# DOG--FIDO--522<br>
# BIRD-CHIRP-2-1<br>
#
# Let's see if our code above will still work?

# %%
# Load the sample data into a list
animal_data2 = ['CAT--FLUFFY410', 'DOG--FIDO--522', 'BIRD-CHIRP-2-1' ]

# processing each animal_data line
for  line in animal_data2:
    animal_type = line[0:5]
    animal_name = line[5:11]
    age = line[11]
    weight = line[12:14]
    
    print(f'{animal_name} is a {animal_type} that is {age} years old and weights {weight} pound(s)')
# Out:
# FLUFFY is a CAT-- that is 4 years old and weights 10 pound(s)
# FIDO-- is a DOG-- that is 5 years old and weights 22 pound(s)
# CHIRP- is a BIRD- that is 2 years old and weights -1 pound(s)

# %% [markdown]
# Aside from changing the initial list that contains our dataset, no coding changes were needed.
#
# Our output looks a little different, but that's because of the different unused character representation. Both of the above examples have their respective unused character values in the data elements.  It's just easier to see in the second example over the first.
#
# Let's try stripping out the unused characters in both examples.

# %%
# working with the second dataset, animal_data2, first.

# processing each animal_data line
for  line in animal_data2:
    animal_type = line[0:5].strip('-')
    animal_name = line[5:11].strip('-')
    age = line[11].strip('-')
    weight = line[12:14].strip('-')
    
    print(f'{animal_name} is a {animal_type} that is {age} years old and weights {weight} pound(s)')
# Out:
# FLUFFY is a CAT that is 4 years old and weights 10 pound(s)
# FIDO is a DOG that is 5 years old and weights 22 pound(s)
# CHIRP is a BIRD that is 2 years old and weights 1 pound(s)

# %%
# repeat the same things with the first set, animal_data.

# processing each animal_data line
for  line in animal_data:
    animal_type = line[0:5].strip('-')
    animal_name = line[5:11].strip('-')
    age = line[11].strip('-')
    weight = line[12:14].strip('-')
    
    print(f'{animal_name} is a {animal_type} that is {age} years old and weights {weight} pound(s)')
# Out:
# FLUFFY is a CAT   that is 4 years old and weights 10 pound(s)
# FIDO   is a DOG   that is 5 years old and weights 22 pound(s)
# CHIRP  is a BIRD  that is 2 years old and weights  1 pound(s)

# %% [markdown]
# <div class="alert alert-success">
# Success!! The two outputs match!
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# ### Back to our assignment
# Section 1 of NISPUF14_CODEBOOK.PDF contains the description of the positional format for nispuf14.dat.
#
# <div class="alert alert-block alert-info">
# <b>Helpful Hint::</b> Combining pyPDF2 and Tabula would work great for  parsing the information within section 1 of NISPUF14_CODEBOOK.PDF. pyPDF2 to retrieve section 1 of the PDF and Tabula for getting the positional formatting information off the PDF and into a pandas dataframe.
# </div>

# %% [markdown]
# Installation reminders from FTE for week3.
# <div class="alert alert-block alert-success">
# <b>Installation - PyPDF2::</b> PyPDF2 can be installed as normal using pip.
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Installation - Tabula::</b> To install the tabula package, you can use pip as shown before. https://pypi.org/project/tabula-py/
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Installation - Java::</b> Note: in order to use tabula, you need to have the latest version of java installed. https://aegis4048.github.io/parse-pdf-files-while-retaining-structure-with-tabula-py has some useful information if you need help getting java installed on your machine.
# </div>

# %% [markdown]
# #### Assignment Approach
#
# <div class="alert alert-block alert-warning">
# <b>One possible solution: </b> Students are encouraged to define their approach when completing any assignment in this class.  Below, I have shared my approach to the assignment for this week.  Feel free to use some or all of this design, if you'd like.
# </div>
#
#
#
# for each line in the file:
#
#     data_line = new list
#     for each variable (line) found in the dataframe:
#         create a dictionary with variable name as key,
#         use start / end position numbers as a slice to give the dictionary's value
#         append dictionary to data_line
#     write data_line to CSV file
#
# <hr>

# %% [markdown]
# ## <b>This is where my Week 5 assignment submittal begins:</b>

# %%
#import PyPDF2 
from PyPDF2 import PdfFileReader, PdfFileWriter,PdfFileMerger

# create a file object for our PDF
pdfFileObj = open('data_wk5/NISPUF14_CODEBOOK.PDF', 'rb') 

# create an object to access the PDF
pdfReader = PdfFileReader(pdfFileObj)

# %%
#Check the number of pages. (Remember it should be 250 pages.)
print(pdfReader.numPages)
# Out:
# 250

# %%
# creating a page object - pdfReader starts at index 0 but we want to see if the first page of variables print.
pageObj = pdfReader.getPage(4) 

# store the text into a string
page_string = pageObj.extractText()

# display the text on the selected page
page_string
# Out:
# 'Codebook and Unweighted Frequencies for the 2014 NIS Public-Use FileSECTION INDEX OF VARIABLESPage 1Codebook and Unweighted Frequencies for the 2014 NIS Public-Use File Page 1 Begin End Variable Name \nPosition Position Section Variable Label SEQNUMC 1 6 1 UNIQUE CHILD IDENTIFIER SEQNUMHH 7 11 1 UNIQUE HOUSEHOLD IDENTIFIER PDAT 12 12 1 CHILD HAS ADEQUATE PROVIDER DATA PROVWT_D 13 31 1 FINAL DUAL-FRAME PROVIDER-PHASE WEIGHT (EXCLUDES TERRITORIES) PROVWT_D_TERR 32 50 1 FINAL DUAL-FRAME PROVIDER-PHASE WEIGHT INCLUDING \nTERRITORIES RDDWT_D 51 69 1 FINAL DUAL-FRAME RDD-PHASE WEIGHT (EXCLUDES \nTERRITORIES) RDDWT_D_TERR 70 88 1 FINAL DUAL-FRAME RDD-PHASE WEIGHT INCLUDING \nTERRITORIES STRATUM 89 92 1 STRATUM VARIABLE FOR DUAL-FRAME VARIANCE ESTIMATION YEAR 93 96 1 YEAR OF INTERVIEW AGECPOXR 97 97 2 AGE IN MONTHS AT CHICKEN POX DISEASE (RECODE) HAD_CPOX 98 99 2 CHILD EVER HAD CHICKEN POX DISEASE? SHOTCARD 100 100 2 SHOT CARD USE FLAG AGEGRP 101 101 3 AGE CATEGORY OF CHILD (19-23, 24-29, 30-35 MO) (RECODE) BF_ENDR06 102 109 3 DURATION OF BREAST FEEDING IN DAYS (RECODE) BF_EXCLR06 110 117 3 DURATION OF EXCLUSIVE BREAST/FORMULA FEEDING IN DAYS \n(RECODE) BF_FORMR08 118 125 3 AGE IN DAYS WHEN CHILD FIRST FED FORMULA (RECODE) BFENDFL06 126 126 3 DURATION OF BREAST FEEDING EXCEEDS CHILD AGE IN DAYS, \nWITH BUFFER BFFORMFL06 127 127 3 AGE IN DAYS WHEN CHILD FIRST FED FORMULA EXCEEDS \nCHILD AGE IN DAYS, WITH BUFFER C1R 128 128 3 NUMBER OF PEOPLE IN HOUSEHOLD (RECODE) C5R 129 130 3 RELATIONSHIP OF RESPONDENT TO CHILD (RECODE) CBF_01 131 132 3 WAS CHILD EVER BREAST FED OR FED BREAST MILK? CEN_REG 133 133 3 CENSUS REGION BASED ON TRUE STATE OF RESIDENCE CHILDNM 134 134 3 NUMBER OF CHILDREN LESS THAN 18 YEARS IN HH (RECODE) CWIC_01 135 136 3 CHILD EVER RECEIVED WIC BENEFITS? CWIC_02 137 138 3 CHILD CURRENTLY RECEIVING WIC BENEFITS? EDUC1 139 139 3 EDUCATION OF MOTHER CATEGORIES (RECODE) FRSTBRN 140 140 3 FIRST BORN STATUS OF CHILD I_HISP_K 141 141 3 HISPANIC ORIGIN OF CHILD INCPORAR 142 157 3 INCOME TO POVERTY RATIO (RECODE) INCPOV1 158 158 3 POVERTY STATUS INCQ298A 159 160 3 FAMILY INCOME CATEGORIES (RECODE) INTRP 161 161 3 PHONE INTERRUPTION OF 7 DAYS OR MORE IN PAST YEAR? LANGUAGE 162 162 3 LANGUAGE IN WHICH INTERVIEW WAS CONDUCTED M_AGEGRP 163 163 3 AGE OF MOTHER CATEGORIES (RECODE) '

# %%
def make_pdf_of_single_page(page_num):
    # same as above
    pdfWriter = PdfFileWriter()
    pdfWriter.addPage(pdfReader.getPage(page_num - 1))

    # construct a unique filename
    out_filename = 'data_wk5/page_' + str(page_num) + '.pdf'
    
    # create a new PDF 
    with open(out_filename, 'wb') as out:
        pdfWriter.write(out)

# %%
# remember range(i,n) generates an iterator to progress integers starting with i upto n-1
# https://www.tutorialspoint.com/python3/python_for_loop.htm
for num in range(5,22):
    make_pdf_of_single_page(num)

# %%
# verify that the pdfs where created
# !dir /S page*
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 34A7-90A0
#
#  Directory of C:\Users\Stacey\Desktop\RU\MSDE621\WeeklyContent\data_wk3
#
# 11/18/2019  08:31 AM            26,004 page_10.pdf
# 11/18/2019  08:31 AM            26,052 page_11.pdf
# 11/18/2019  08:31 AM            25,972 page_12.pdf
# 11/18/2019  08:31 AM            26,033 page_13.pdf
# 11/18/2019  08:31 AM            26,209 page_14.pdf
# 11/18/2019  08:31 AM            25,828 page_15.pdf
#                6 File(s)        156,098 bytes
#
#  Directory of C:\Users\Stacey\Desktop\RU\MSDE621\WeeklyContent\data_wk5
#
# 12/15/2019  03:46 PM             5,773 page_10.pdf
# 12/15/2019  03:46 PM             5,699 page_11.pdf
# 12/15/2019  03:46 PM             5,902 page_12.pdf
# 12/15/2019  03:46 PM             5,929 page_13.pdf
# 12/15/2019  03:46 PM             5,959 page_14.pdf
# 12/15/2019  03:46 PM             5,885 page_15.pdf
# 12/15/2019  03:46 PM             5,860 page_16.pdf
# 12/15/2019  03:46 PM             5,949 page_17.pdf
# 12/15/2019  03:46 PM             5,973 page_18.pdf
# 12/15/2019  03:46 PM             5,974 page_19.pdf
# 12/15/2019  03:46 PM             5,973 page_20.pdf
# 12/15/2019  03:46 PM             5,399 page_21.pdf
# 12/15/2019  03:46 PM             6,575 page_5.pdf
# 12/15/2019  03:46 PM             6,261 page_6.pdf
# 12/15/2019  03:46 PM             5,670 page_7.pdf
# 12/15/2019  03:46 PM             5,615 page_8.pdf
# 12/15/2019  03:46 PM             5,580 page_9.pdf
#               17 File(s)         99,976 bytes
#
#      Total Files Listed:
#               23 File(s)        256,074 bytes
#                0 Dir(s)  31,596,388,352 bytes free

# %%
# let's create a list of all the pdfs we just created
import glob

pdf_list = [f for f in glob.glob('data_wk5/page_*')]

# %%
#Print the list
pdf_list
# Out:
# ['data_wk5\\page_10.pdf',
#  'data_wk5\\page_11.pdf',
#  'data_wk5\\page_12.pdf',
#  'data_wk5\\page_13.pdf',
#  'data_wk5\\page_14.pdf',
#  'data_wk5\\page_15.pdf',
#  'data_wk5\\page_16.pdf',
#  'data_wk5\\page_17.pdf',
#  'data_wk5\\page_18.pdf',
#  'data_wk5\\page_19.pdf',
#  'data_wk5\\page_20.pdf',
#  'data_wk5\\page_21.pdf',
#  'data_wk5\\page_5.pdf',
#  'data_wk5\\page_6.pdf',
#  'data_wk5\\page_7.pdf',
#  'data_wk5\\page_8.pdf',
#  'data_wk5\\page_9.pdf']

# %%
#Resort the list so the page numbers are in natural order
from natsort import natsorted
pdf_list = natsorted(pdf_list)

# %%
# verify they all contain a single page and are now in order.
for pdf in pdf_list:
    n_pdfFileObj = open(pdf, 'rb') 
    n_pdfReader = PdfFileReader(n_pdfFileObj) 
    print(pdf,'has', n_pdfReader.numPages, 'page(s)') 
    
    # close the fileobjects
    n_pdfFileObj.close()
# Out:
# data_wk5\page_5.pdf has 1 page(s)
# data_wk5\page_6.pdf has 1 page(s)
# data_wk5\page_7.pdf has 1 page(s)
# data_wk5\page_8.pdf has 1 page(s)
# data_wk5\page_9.pdf has 1 page(s)
# data_wk5\page_10.pdf has 1 page(s)
# data_wk5\page_11.pdf has 1 page(s)
# data_wk5\page_12.pdf has 1 page(s)
# data_wk5\page_13.pdf has 1 page(s)
# data_wk5\page_14.pdf has 1 page(s)
# data_wk5\page_15.pdf has 1 page(s)
# data_wk5\page_16.pdf has 1 page(s)
# data_wk5\page_17.pdf has 1 page(s)
# data_wk5\page_18.pdf has 1 page(s)
# data_wk5\page_19.pdf has 1 page(s)
# data_wk5\page_20.pdf has 1 page(s)
# data_wk5\page_21.pdf has 1 page(s)

# %%
# creating pdf file merger object 
pdfMerger = PdfFileMerger() 

# appending the individual pdfs to the merger object
for pdf in pdf_list:
    pdfMerger.append(PdfFileReader(pdf),'rb')    
        
# writing combined pdf to output pdf file 
with open('data_wk5/merged.pdf', 'wb') as new_file: 
    pdfMerger.write(new_file)

# %%
m_pdfFileObj = open('data_wk5/merged.pdf', 'rb') 
m_pdfReader = PdfFileReader(m_pdfFileObj) 
print(m_pdfReader.numPages)
# Out:
# 17

# %%
# looking at last page_21.pdf
v_pdfFileObj = open('data_wk5/page_21.pdf', 'rb') 
v_pdfReader = PdfFileReader(v_pdfFileObj) 
v_pageObj = v_pdfReader.getPage(0) 

# look at the first 100 characters
print(v_pageObj.extractText()[:200])
# Out:
# Codebook and Unweighted Frequencies for the 2014 NIS Public-Use File Page 17 Begin End Variable Name
# Position Position Section Variable Label XVRCTY7 850 850 9 VARICELLA-CONTAINING VACCINATION #7 TYP

# %%
# looking at merged.pdf last page 17
m_pageObj = m_pdfReader.getPage(16) 

# only need the first 100 characters for comparison
print(m_pageObj.extractText()[:200])
# Out:
# Codebook and Unweighted Frequencies for the 2014 NIS Public-Use File Page 17 Begin End Variable Name
# Position Position Section Variable Label XVRCTY7 850 850 9 VARICELLA-CONTAINING VACCINATION #7 TYP

# %%
# import tabula library
import tabula

# pdf location
pdf_file = "data_wk5/merged.pdf"

# read our pdf into a pandas dataframe
df_NIS = tabula.read_pdf(pdf_file, pages='all')

# %%
#View head of dataframe
df_NIS.head()
# Out:
#   Variable Name Position Position.1 Section  \
# 0       SEQNUMC        1          6       1
# 1      SEQNUMHH        7         11       1
# 2          PDAT       12         12       1
# 3      PROVWT_D       13         31       1
# 4           NaN      NaN        NaN     NaN
#
#                                      Variable Label
# 0                           UNIQUE CHILD IDENTIFIER
# 1                       UNIQUE HOUSEHOLD IDENTIFIER
# 2                  CHILD HAS ADEQUATE PROVIDER DATA
# 3  FINAL DUAL-FRAME PROVIDER-PHASE WEIGHT (EXCLUDES
# 4                                      TERRITORIES)

# %%
#View tail of dataframe
df_NIS.tail()
# Out:
#     Variable Name Position Position.1 Section  \
# 704       INS_4_5      861        862      10
# 705           NaN      NaN        NaN     NaN
# 706         INS_6      863        864      10
# 707           NaN      NaN        NaN     NaN
# 708        INS_11      865        866      10
#
#                                         Variable Label
# 704  IS CHILD COVERED BY INDIAN HEALTH SERVICE, MIL...
# 705               CARE, TRICARE, CHAMPUS, OR CHAMP-VA?
# 706  IS CHILD COVERED BY ANY OTHER HEALTH INSURANCE...
# 707                                         CARE PLAN?
# 708  ANY TIME WHEN CHILD WAS NOT COVERED BY ANY HEALTH

# %%
#View length (# of rows) of dataframe
len(df_NIS)
# Out:
# 709

# %%
#View shape (# of rows, # of columns) of dataframe.
df_NIS.shape
# Out:
# (709, 5)

# %%
#Let's see how many duplicated rows are in dataframe, but keep first.
df_NIS.duplicated(keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 679    False
# 680    False
# 681    False
# 682    False
# 683    False
# 684    False
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# 690    False
# 691    False
# 692    False
# 693    False
# 694    False
# 695     True
# 696    False
# 697    False
# 698    False
# 699    False
# 700    False
# 701    False
# 702    False
# 703    False
# 704    False
# 705    False
# 706    False
# 707    False
# 708    False
# Length: 709, dtype: bool

# %%
#Let's try to drop these duplicate rows. As we know the header may be duplicated due to the pdf merge.
df_NIS.drop_duplicates()
# Out:
#      Variable Name Position Position.1 Section  \
# 0          SEQNUMC        1          6       1
# 1         SEQNUMHH        7         11       1
# 2             PDAT       12         12       1
# 3         PROVWT_D       13         31       1
# 4              NaN      NaN        NaN     NaN
# 5    PROVWT_D_TERR       32         50       1
# 6              NaN      NaN        NaN     NaN
# 7          RDDWT_D       51         69       1
# 9     RDDWT_D_TERR       70         88       1
# 11         STRATUM       89         92       1
# 12            YEAR       93         96       1
# 13        AGECPOXR       97         97       2
# 14        HAD_CPOX       98         99       2
# 15        SHOTCARD      100        100       2
# 16          AGEGRP      101        101       3
# 17       BF_ENDR06      102        109       3
# 18      BF_EXCLR06      110        117       3
# 19             NaN      NaN        NaN     NaN
# 20      BF_FORMR08      118        125       3
# 21       BFENDFL06      126        126       3
# 22             NaN      NaN        NaN     NaN
# 23      BFFORMFL06      127        127       3
# 24             NaN      NaN        NaN     NaN
# 25             C1R      128        128       3
# 26             C5R      129        130       3
# 27          CBF_01      131        132       3
# 28         CEN_REG      133        133       3
# 29         CHILDNM      134        134       3
# 30         CWIC_01      135        136       3
# 31         CWIC_02      137        138       3
# ..             ...      ...        ...     ...
# 678        XPOLTY8      825        825       9
# 679        XPOLTY9      826        826       9
# 680        XROTTY1      827        828       9
# 681        XROTTY2      829        830       9
# 682        XROTTY3      831        832       9
# 683        XROTTY4      833        834       9
# 684        XROTTY5      835        836       9
# 685        XROTTY6      837        837       9
# 686        XROTTY7      838        838       9
# 687        XROTTY8      839        839       9
# 688        XROTTY9      840        840       9
# 689        XVRCTY1      841        842       9
# 690        XVRCTY2      843        844       9
# 691        XVRCTY3      845        846       9
# 692        XVRCTY4      847        847       9
# 693        XVRCTY5      848        848       9
# 694        XVRCTY6      849        849       9
# 696        XVRCTY7      850        850       9
# 697        XVRCTY8      851        851       9
# 698        XVRCTY9      852        852       9
# 699          INS_1      853        854      10
# 700            NaN      NaN        NaN     NaN
# 701          INS_2      855        856      10
# 702          INS_3      857        858      10
# 703         INS_3A      859        860      10
# 704        INS_4_5      861        862      10
# 705            NaN      NaN        NaN     NaN
# 706          INS_6      863        864      10
# 707            NaN      NaN        NaN     NaN
# 708         INS_11      865        866      10
#
#                                         Variable Label
# 0                              UNIQUE CHILD IDENTIFIER
# 1                          UNIQUE HOUSEHOLD IDENTIFIER
# 2                     CHILD HAS ADEQUATE PROVIDER DATA
# 3     FINAL DUAL-FRAME PROVIDER-PHASE WEIGHT (EXCLUDES
# 4                                         TERRITORIES)
# 5     FINAL DUAL-FRAME PROVIDER-PHASE WEIGHT INCLUDING
# 6                                          TERRITORIES
# 7          FINAL DUAL-FRAME RDD-PHASE WEIGHT (EXCLUDES
# 9          FINAL DUAL-FRAME RDD-PHASE WEIGHT INCLUDING
# 11   STRATUM VARIABLE FOR DUAL-FRAME VARIANCE ESTIM...
# 12                                   YEAR OF INTERVIEW
# 13       AGE IN MONTHS AT CHICKEN POX DISEASE (RECODE)
# 14                 CHILD EVER HAD CHICKEN POX DISEASE?
# 15                                  SHOT CARD USE FLAG
# 16   AGE CATEGORY OF CHILD (19-23, 24-29, 30-35 MO)...
# 17         DURATION OF BREAST FEEDING IN DAYS (RECODE)
# 18   DURATION OF EXCLUSIVE BREAST/FORMULA FEEDING I...
# 19                                            (RECODE)
# 20   AGE IN DAYS WHEN CHILD FIRST FED FORMULA (RECODE)
# 21   DURATION OF BREAST FEEDING EXCEEDS CHILD AGE I...
# 22                                         WITH BUFFER
# 23    AGE IN DAYS WHEN CHILD FIRST FED FORMULA EXCEEDS
# 24                      CHILD AGE IN DAYS, WITH BUFFER
# 25              NUMBER OF PEOPLE IN HOUSEHOLD (RECODE)
# 26        RELATIONSHIP OF RESPONDENT TO CHILD (RECODE)
# 27       WAS CHILD EVER BREAST FED OR FED BREAST MILK?
# 28      CENSUS REGION BASED ON TRUE STATE OF RESIDENCE
# 29   NUMBER OF CHILDREN LESS THAN 18 YEARS IN HH (R...
# 30                   CHILD EVER RECEIVED WIC BENEFITS?
# 31             CHILD CURRENTLY RECEIVING WIC BENEFITS?
# ..                                                 ...
# 678          POLIO-CONTAINING VACCINATION #8 TYPE CODE
# 679          POLIO-CONTAINING VACCINATION #9 TYPE CODE
# 680      ROTAVIRUS-CONTAINING VACCINATION #1 TYPE CODE
# 681      ROTAVIRUS-CONTAINING VACCINATION #2 TYPE CODE
# 682      ROTAVIRUS-CONTAINING VACCINATION #3 TYPE CODE
# 683      ROTAVIRUS-CONTAINING VACCINATION #4 TYPE CODE
# 684      ROTAVIRUS-CONTAINING VACCINATION #5 TYPE CODE
# 685      ROTAVIRUS-CONTAINING VACCINATION #6 TYPE CODE
# 686      ROTAVIRUS-CONTAINING VACCINATION #7 TYPE CODE
# 687      ROTAVIRUS-CONTAINING VACCINATION #8 TYPE CODE
# 688      ROTAVIRUS-CONTAINING VACCINATION #9 TYPE CODE
# 689      VARICELLA-CONTAINING VACCINATION #1 TYPE CODE
# 690      VARICELLA-CONTAINING VACCINATION #2 TYPE CODE
# 691      VARICELLA-CONTAINING VACCINATION #3 TYPE CODE
# 692      VARICELLA-CONTAINING VACCINATION #4 TYPE CODE
# 693      VARICELLA-CONTAINING VACCINATION #5 TYPE CODE
# 694      VARICELLA-CONTAINING VACCINATION #6 TYPE CODE
# 696      VARICELLA-CONTAINING VACCINATION #7 TYPE CODE
# 697      VARICELLA-CONTAINING VACCINATION #8 TYPE CODE
# 698      VARICELLA-CONTAINING VACCINATION #9 TYPE CODE
# 699  IS CHILD COVERED BY HEALTH INSURANCE PROVIDED ...
# 700                                 EMPLOYER OR UNION?
# 701             IS CHILD COVERED BY ANY MEDICAID PLAN?
# 702                        IS CHILD COVERED BY S-CHIP?
# 703   IS CHILD COVERED BY ANY MEDICAID PLAN OR S-CHIP?
# 704  IS CHILD COVERED BY INDIAN HEALTH SERVICE, MIL...
# 705               CARE, TRICARE, CHAMPUS, OR CHAMP-VA?
# 706  IS CHILD COVERED BY ANY OTHER HEALTH INSURANCE...
# 707                                         CARE PLAN?
# 708  ANY TIME WHEN CHILD WAS NOT COVERED BY ANY HEALTH
#
# [542 rows x 5 columns]

# %% [markdown]
# Notice the dataframe still contains the NaN rows for the Variable Label column that populated in a different row.

# %%
#Look at dataframe shape again after the duplicate drops.
df_NIS.shape
# Out:
# (709, 5)

# %% [markdown]
# <b>That didn't work....</b> Looks like the duplicates remain and the shape is the same as before. Hhmmmmmm.

# %%
#Convert merged PDF into CSV file
tabula.convert_into("data_wk5/merged.pdf", "data_wk5/output.csv", output_format="csv", pages='all')

# %%
# Let's just subset the columns Variable Name, begin position and end position.
#We will rename the columns while we are at it.
NIS_subset = df_NIS[['Variable Name', 'Position', 'Position.1']].rename(columns = {"Variable Name" : "Variable Name", "Position" : "Begin", "Position.1" : "End"})
NIS_subset.head()
# Out:
#   Variable Name Begin  End
# 0       SEQNUMC     1    6
# 1      SEQNUMHH     7   11
# 2          PDAT    12   12
# 3      PROVWT_D    13   31
# 4           NaN   NaN  NaN

# %%
#Let's drop NaN values
NIS_dropna = NIS_subset.dropna()
print(NIS_dropna.shape)
# Out:
# (477, 3)

# %%
#Let's take a look at the first 12 rows
NIS_dropna.head(12)
# Out:
#     Variable Name Begin  End
# 0         SEQNUMC     1    6
# 1        SEQNUMHH     7   11
# 2            PDAT    12   12
# 3        PROVWT_D    13   31
# 5   PROVWT_D_TERR    32   50
# 7         RDDWT_D    51   69
# 9    RDDWT_D_TERR    70   88
# 11        STRATUM    89   92
# 12           YEAR    93   96
# 13       AGECPOXR    97   97
# 14       HAD_CPOX    98   99
# 15       SHOTCARD   100  100

# %%
#Now let's look at the last 12 rows 
NIS_dropna.tail(12)
# Out:
#      Variable Name     Begin       End
# 694        XVRCTY6       849       849
# 695  Variable Name  Position  Position
# 696        XVRCTY7       850       850
# 697        XVRCTY8       851       851
# 698        XVRCTY9       852       852
# 699          INS_1       853       854
# 701          INS_2       855       856
# 702          INS_3       857       858
# 703         INS_3A       859       860
# 704        INS_4_5       861       862
# 706          INS_6       863       864
# 708         INS_11       865       866

# %% [markdown]
# <b>Great!</b> Looks like the duplicate or NaN values in row 8 and 10 were removed from the dataframe.<br>
# We also see that row 695 is still re-appearing for the duplicate headers from the PDF document. We will need to take caare of that too....

# %%
#Let's create a final "clean" version dataframe to solve the above problem...
NIS_dfclean = NIS_dropna.drop_duplicates(subset="Variable Name")

# %%
#Take a look at the shape.
NIS_dfclean.shape
# Out:
# (462, 3)

# %%
#Loo at tail to confirm the drop.
NIS_dfclean.tail(12)
# Out:
#     Variable Name Begin  End
# 693       XVRCTY5   848  848
# 694       XVRCTY6   849  849
# 696       XVRCTY7   850  850
# 697       XVRCTY8   851  851
# 698       XVRCTY9   852  852
# 699         INS_1   853  854
# 701         INS_2   855  856
# 702         INS_3   857  858
# 703        INS_3A   859  860
# 704       INS_4_5   861  862
# 706         INS_6   863  864
# 708        INS_11   865  866

# %% [markdown]
# <b>This is better!</b> Looks like the duplicates dropped and NaN values are gone. The shape shows 462 rows which is more reasonable for the 3 column values (Variable Name, Begin, End) that we only care about for the purpose of this assignment.<br>
# <b>Notice</b> how line 695 of the repeated header from each PDF page has been dropped. Yay!

# %%
#Let's try to save the dataframe to CSV.
NIS_csv = NIS_dfclean.to_csv(header=True, line_terminator='\n')

# %%
#Print CSV...
NIS_csv
# Out:
# ',Variable Name,Begin,End\n0,SEQNUMC,1,6\n1,SEQNUMHH,7,11\n2,PDAT,12,12\n3,PROVWT_D,13,31\n5,PROVWT_D_TERR,32,50\n7,RDDWT_D,51,69\n9,RDDWT_D_TERR,70,88\n11,STRATUM,89,92\n12,YEAR,93,96\n13,AGECPOXR,97,97\n14,HAD_CPOX,98,99\n15,SHOTCARD,100,100\n16,AGEGRP,101,101\n17,BF_ENDR06,102,109\n18,BF_EXCLR06,110,117\n20,BF_FORMR08,118,125\n21,BFENDFL06,126,126\n23,BFFORMFL06,127,127\n25,C1R,128,128\n26,C5R,129,130\n27,CBF_01,131,132\n28,CEN_REG,133,133\n29,CHILDNM,134,134\n30,CWIC_01,135,136\n31,CWIC_02,137,138\n32,EDUC1,139,139\n33,FRSTBRN,140,140\n34,I_HISP_K,141,141\n35,INCPORAR,142,157\n36,INCPOV1,158,158\n37,INCQ298A,159,160\n38,INTRP,161,161\n39,LANGUAGE,162,162\n40,M_AGEGRP,163,163\n41,Variable Name,Position,Position\n42,MARITAL2,164,164\n43,MOBIL_I,165,165\n45,NUM_PHONE,166,167\n47,NUM_CELLS_HH,168,169\n49,NUM_CELLS_PARENTS,170,171\n51,RACE_K,172,172\n52,RACEETHK,173,173\n53,RENT_OWN,174,175\n55,SEX,176,176\n56,ESTIAP14,177,179\n57,EST_GRANT,180,181\n59,STATE,182,183\n60,D6R,184,184\n62,D7,185,185\n64,N_PRVR,186,186\n66,PROV_FAC,187,187\n67,REGISTRY,188,188\n69,VFC_ORDER,189,189\n71,HEP_BRTH,190,190\n72,HEP_FLAG,191,191\n73,P_NUHEPX,192,192\n76,P_NUHIBX,193,193\n79,P_NUHPHB,194,194\n82,P_NUMDAH,195,195\n85,P_NUMDHI,196,196\n87,P_NUMDIH,197,197\n90,P_NUMDTA,198,198\n93,P_NUMDTP,199,199\n96,P_NUMFLU,200,200\n100,P_NUMFLUL,201,201\n104,P_NUMFLUM,202,202\n108,P_NUMFLUN,203,203\n112,P_NUMHEA,204,204\n115,P_NUMHEN,205,205\n119,P_NUMHEP,206,206\n122,P_NUMHG,207,207\n125,P_NUMHHY,208,208\n128,P_NUMHIB,209,209\n131,P_NUMHIN,210,210\n135,P_NUMHION,211,211\n137,P_NUMHM,212,212\n140,P_NUMHS,213,213\n143,P_NUMIPV,214,214\n146,P_NUMMCN,215,215\n150,P_NUMMMR,216,216\n153,P_NUMMMRX,217,217\n156,P_NUMMMX,218,218\n159,P_NUMMP,219,219\n162,P_NUMMPR,220,220\n165,P_NUMMRV,221,221\n168,P_NUMMS,222,222\n171,P_NUMMSM,223,223\n174,P_NUMMSR,224,224\n177,P_NUMOLN,225,225\n180,P_NUMOPV,226,226\n183,P_NUMPCV,227,227\n185,P_NUMPCP,228,228\n189,P_NUMPCC,229,229\n193,P_NUMPCC7,230,230\n197,P_NUMPCC13,231,231\n201,P_NUMPCCN,232,232\n205,P_NUMPCN,233,233\n209,P_NUMPOL,234,234\n212,P_NUMRB,235,235\n215,P_NUMRG,236,236\n218,P_NUMRM,237,237\n221,P_NUMRO,238,238\n225,P_NUMROT,239,239\n228,P_NUMTPN,240,240\n232,P_NUMVRC,241,241\n234,P_NUMVRN,242,242\n238,P_NUMVRX,243,243\n241,P_U12VRC,244,244\n245,P_UTD331,245,245\n248,P_UTD431,246,246\n251,P_UTDHEP,247,247\n255,P_UTDHEPA1,248,248\n259,P_UTDHEPA2,249,249\n263,P_UTDHIB,250,250\n266,P_UTDHIB_ROUT_S,251,251\n271,P_UTDHIB_SHORT_S,252,252\n276,P_UTDMCV,253,253\n280,P_UTDMMX,254,254\n283,P_UTDPC3,255,255\n285,P_UTDPCV,256,256\n289,P_UTDPCVB13,257,257\n294,P_UTDPOL,258,258\n297,P_UTDROT_S,259,259\n302,P_UTDTP3,260,260\n305,P_UTDTP4,261,261\n308,PU431331,262,262\n311,P_UTD431H31_ROUT_S,263,263\n316,PU431_31,264,264\n320,PU4313313,265,265\n324,P_UTD431H313_ROUT_S,266,266\n329,PU4313314,267,267\n333,P_UTD431H314_ROUT_S,268,268\n335,PU431_314,269,269\n339,PUT43133,270,270\n342,P_UTD431H3_ROUT_S,271,271\n346,PUTD4313,272,272\n349,P_UTD431H_ROUT_S,273,273\n353,U1D_HEP,274,274\n355,U2D_HEP,275,275\n357,U3D_HEP,276,276\n359,DDTP1,277,280\n360,DDTP2,281,284\n361,DDTP3,285,288\n362,DDTP4,289,292\n363,DDTP5,293,296\n364,DDTP6,297,300\n365,DDTP7,301,301\n366,DDTP8,302,302\n367,DDTP9,303,303\n368,DFLU1,304,307\n370,DFLU2,308,311\n372,DFLU3,312,315\n374,DFLU4,316,319\n376,DFLU5,320,323\n378,DFLU6,324,327\n380,DFLU7,328,328\n382,DFLU8,329,329\n384,DFLU9,330,330\n386,DHEPA1,331,334\n387,DHEPA2,335,338\n388,DHEPA3,339,342\n389,DHEPA4,343,346\n390,DHEPA5,347,347\n391,DHEPA6,348,348\n392,DHEPA7,349,349\n393,DHEPA8,350,350\n394,DHEPA9,351,351\n395,DHEPB1,352,355\n396,DHEPB2,356,359\n397,DHEPB3,360,363\n398,DHEPB4,364,367\n399,DHEPB5,368,371\n400,DHEPB6,372,374\n401,DHEPB7,375,377\n402,DHEPB8,378,378\n403,DHEPB9,379,379\n404,DHIB1,380,383\n405,DHIB2,384,387\n406,DHIB3,388,391\n407,DHIB4,392,395\n408,DHIB5,396,399\n409,DHIB6,400,402\n410,DHIB7,403,405\n411,DHIB8,406,406\n412,DHIB9,407,407\n413,DMMR1,408,411\n414,DMMR2,412,415\n415,DMMR3,416,418\ ...

# %%
#Look at the CSV type
type(NIS_csv)
# Out:
# str

# %%
#Create a new list of the CSV file and print

NIS_csvline = []
for line in NIS_csv:
    NIS_csvline.append(line)

NIS_csvline
# Out:
# [',',
#  'V',
#  'a',
#  'r',
#  'i',
#  'a',
#  'b',
#  'l',
#  'e',
#  ' ',
#  'N',
#  'a',
#  'm',
#  'e',
#  ',',
#  'B',
#  'e',
#  'g',
#  'i',
#  'n',
#  ',',
#  'E',
#  'n',
#  'd',
#  '\n',
#  '0',
#  ',',
#  'S',
#  'E',
#  'Q',
#  'N',
#  'U',
#  'M',
#  'C',
#  ',',
#  '1',
#  ',',
#  '6',
#  '\n',
#  '1',
#  ',',
#  'S',
#  'E',
#  'Q',
#  'N',
#  'U',
#  'M',
#  'H',
#  'H',
#  ',',
#  '7',
#  ',',
#  '1',
#  '1',
#  '\n',
#  '2',
#  ',',
#  'P',
#  'D',
#  'A',
#  'T',
#  ',',
#  '1',
#  '2',
#  ',',
#  '1',
#  '2',
#  '\n',
#  '3',
#  ',',
#  'P',
#  'R',
#  'O',
#  'V',
#  'W',
#  'T',
#  '_',
#  'D',
#  ',',
#  '1',
#  '3',
#  ',',
#  '3',
#  '1',
#  '\n',
#  '5',
#  ',',
#  'P',
#  'R',
#  'O',
#  'V',
#  'W',
#  'T',
#  '_',
#  'D',
#  '_',
#  'T',
#  'E',
#  'R',
#  'R',
#  ',',
#  '3',
#  '2',
#  ',',
#  '5',
#  '0',
#  '\n',
#  '7',
#  ',',
#  'R',
#  'D',
#  'D',
#  'W',
#  'T',
#  '_',
#  'D',
#  ',',
#  '5',
#  '1',
#  ',',
#  '6',
#  '9',
#  '\n',
#  '9',
#  ',',
#  'R',
#  'D',
#  'D',
#  'W',
#  'T',
#  '_',
#  'D',
#  '_',
#  'T',
#  'E',
#  'R',
#  'R',
#  ',',
#  '7',
#  '0',
#  ',',
#  '8',
#  '8',
#  '\n',
#  '1',
#  '1',
#  ',',
#  'S',
#  'T',
#  'R',
#  'A',
#  'T',
#  'U',
#  'M',
#  ',',
#  '8',
#  '9',
#  ',',
#  '9',
#  '2',
#  '\n',
#  '1',
#  '2',
#  ',',
#  'Y',
#  'E',
#  'A',
#  'R',
#  ',',
#  '9',
#  '3',
#  ',',
#  '9',
#  '6',
#  '\n',
#  '1',
#  '3',
#  ',',
#  'A',
#  'G',
#  'E',
#  'C',
#  'P',
#  'O',
#  'X',
#  'R',
#  ',',
#  '9',
#  '7',
#  ',',
#  '9',
#  '7',
#  '\n',
#  '1',
#  '4',
#  ',',
#  'H',
#  'A',
#  'D',
#  '_',
#  'C',
#  'P',
#  'O',
#  'X',
#  ',',
#  '9',
#  '8',
#  ',',
#  '9',
#  '9',
#  '\n',
#  '1',
#  '5',
#  ',',
#  'S',
#  'H',
#  'O',
#  'T',
#  'C',
#  'A',
#  'R',
#  'D',
#  ',',
#  '1',
#  '0',
#  '0',
#  ',',
#  '1',
#  '0',
#  '0',
#  '\n',
#  '1',
#  '6',
#  ',',
#  'A',
#  'G',
#  'E',
#  'G',
#  'R',
#  'P',
#  ',',
#  '1',
#  '0',
#  '1',
#  ',',
#  '1',
#  '0',
#  '1',
#  '\n',
#  '1',
#  '7',
#  ',',
#  'B',
#  'F',
#  '_',
#  'E',
#  'N',
#  'D',
#  'R',
#  '0',
#  '6',
#  ',',
#  '1',
#  '0',
#  '2',
#  ',',
#  '1',
#  '0',
#  '9',
#  '\n',
#  '1',
#  '8',
#  ',',
#  'B',
#  'F',
#  '_',
#  'E',
#  'X',
#  'C',
#  'L',
#  'R',
#  '0',
#  '6',
#  ',',
#  '1',
#  '1',
#  '0',
#  ',',
#  '1',
#  '1',
#  '7',
#  '\n',
#  '2',
#  '0',
#  ',',
#  'B',
#  'F',
#  '_',
#  'F',
#  'O',
#  'R',
#  'M',
#  'R',
#  '0',
#  '8',
#  ',',
#  '1',
#  '1',
#  '8',
#  ',',
#  '1',
#  '2',
#  '5',
#  '\n',
#  '2',
#  '1',
#  ',',
#  'B',
#  'F',
#  'E',
#  'N',
#  'D',
#  'F',
#  'L',
#  '0',
#  '6',
#  ',',
#  '1',
#  '2',
#  '6',
#  ',',
#  '1',
#  '2',
#  '6',
#  '\n',
#  '2',
#  '3',
#  ',',
#  'B',
#  'F',
#  'F',
#  'O',
#  'R',
#  'M',
#  'F',
#  'L',
#  '0',
#  '6',
#  ',',
#  '1',
#  '2',
#  '7',
#  ',',
#  '1',
#  '2',
#  '7',
#  '\n',
#  '2',
#  '5',
#  ',',
#  'C',
#  '1',
#  'R',
#  ',',
#  '1',
#  '2',
#  '8',
#  ',',
#  '1',
#  '2',
#  '8',
#  '\n',
#  '2',
#  '6',
#  ',',
#  'C',
#  '5',
#  'R',
#  ',',
#  '1',
#  '2',
#  '9',
#  ',',
#  '1',
#  '3',
#  '0',
#  '\n',
#  '2',
#  '7',
#  ',',
#  'C',
#  'B',
#  'F',
#  '_',
#  '0',
#  '1',
#  ',',
#  '1',
#  '3',
#  '1',
#  ',',
#  '1',
#  '3',
#  '2',
#  '\n',
#  '2',
#  '8',
#  ',',
#  'C',
#  'E',
#  'N',
#  '_',
#  'R',
#  'E',
#  'G',
#  ',',
#  '1',
#  '3',
#  '3',
#  ',',
#  '1',
#  '3',
#  '3',
#  '\n',
#  '2',
#  '9',
#  ',',
#  'C',
#  'H',
#  'I',
#  'L',
#  'D',
#  'N',
#  'M',
#  ',',
#  '1',
#  '3',
#  '4',
#  ',',
#  '1',
#  '3',
#  '4',
#  '\n',
#  '3',
#  '0',
#  ',',
#  'C',
#  'W',
#  'I',
#  'C',
#  '_',
#  '0',
#  '1',
#  ',',
#  '1',
#  '3',
#  '5',
#  ',',
#  '1',
#  '3',
#  '6',
#  '\n',
#  '3',
#  '1',
#  ',',
#  'C',
#  'W',
#  'I',
#  'C',
#  '_',
#  '0',
#  '2',
#  ',',
#  '1',
#  '3',
#  '7',
#  ',',
#  '1',
#  '3',
#  '8',
#  '\n',
#  '3',
#  '2',
#  ',',
#  'E',
#  'D',
#  'U',
#  'C',
#  '1',
#  ',',
#  '1',
#  '3',
#  '9',
#  ',',
#  '1',
#  '3',
#  '9',
#  '\n',
#  '3',
#  '3',
#  ',',
#  'F',
#  'R',
#  'S',
#  'T',
#  'B',
#  'R',
#  'N',
#  ',',
#  '1',
#  '4',
#  '0',
#  ',',
#  '1',
#  '4',
#  '0',
#  '\n',
#  '3',
#  '4',
#  ',',
#  'I',
#  '_',
#  'H',
#  'I',
#  'S',
#  'P',
#  '_',
#  'K',
#  ',',
#  '1',
#  '4',
#  '1',
#  ',',
#  '1',
#  '4',
#  '1',
#  '\n',
#  '3',
#  '5',
#  ',',
#  'I',
#  'N',
#  'C',
#  'P',
#  'O',
#  'R',
#  'A',
#  'R',
#  ',',
#  '1',
#  '4',
#  '2',
#  ',',
#  '1',
#  '5',
#  '7',
#  '\n',
#  '3',
#  '6',
#  ',',
#  'I',
#  'N',
#  'C',
#  'P',
#  'O',
#  'V',
#  '1',
#  ',',
#  '1',
#  '5',
#  '8',
#  ',',
#  '1',
#  '5',
#  '8',
#  '\n',
#  '3',
#  '7',
#  ',',
#  'I',
#  'N',
#  'C',
#  'Q',
#  '2',
#  '9',
#  '8',
#  'A',
#  ',',
#  '1',
#  '5',
#  '9',
#  ',',
#  '1',
#  '6',
#  '0',
#  '\n',
#  '3',
#  '8',
#  ',',
#  'I',
#  'N',
#  'T',
#  'R',
#  'P',
#  ',',
#  '1',
#  '6',
#  '1',
#  ',',
#  '1',
#  '6',
#  '1',
#  '\n',
#  '3',
#  '9',
#  ',',
#  'L',
#  'A',
#  'N',
#  'G',
#  'U',
#  'A',
#  'G',
#  'E',
#  ',',
#  '1',
#  '6',
#  '2',
#  ',',
#  '1',
#  '6',
#  '2',
#  '\n',
#  '4',
#  '0',
#  ',',
#  'M',
#  '_',
#  'A',
#  'G',
#  'E',
#  'G',
#  'R',
#  'P',
#  ',',
#  '1',
#  '6',
#  '3',
#  ',',
#  '1',
#  '6',
#  '3',
#  '\n',
#  '4',
#  '1',
#  ',',
#  'V',
#  'a',
#  'r',
#  'i',
#  'a',
#  'b',
#  'l',
#  'e',
#  ' ',
#  'N',
#  'a',
#  'm',
#  'e',
#  ',',
#  'P',
#  'o',
#  's',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  'P',
#  'o',
#  's',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  '\n',
#  '4',
#  '2',
#  ',',
#  'M',
#  'A',
#  'R',
#  'I',
#  'T',
#  'A',
#  'L',
#  '2',
#  ',',
#  '1',
#  '6',
#  '4',
#  ',',
#  '1',
#  '6',
#  '4',
#  '\n',
#  '4',
#  '3',
#  ',',
#  'M',
#  'O',
#  'B',
#  'I',
#  'L',
#  '_',
#  'I',
#  ',',
#  '1',
#  '6',
#  '5',
#  ',',
#  '1',
#  '6',
#  '5',
#  '\n',
#  '4',
#  '5',
#  ',',
#  'N',
#  'U',
#  'M',
#  '_',
#  'P',
#  'H',
#  'O',
#  'N',
#  'E',
#  ',',
#  '1',
#  '6',
#  '6',
#  ',',
#  '1',
#  '6',
#  '7',
#  '\n',
#  '4',
#  '7',
#  ',',
#  'N',
#  'U',
#  'M',
#  '_',
#  'C',
#  'E',
#  'L',
#  'L',
#  'S',
#  '_',
#  'H',
#  'H',
#  ',',
#  '1',
#  '6',
#  '8',
#  ',',
#  '1',
#  '6',
#  '9',
#  '\n',
#  '4',
#  '9',
#  ',',
#  'N',
#  'U',
#  'M',
#  '_',
#  'C',
#  'E',
#  'L',
#  'L',
#  'S',
#  '_',
#  'P',
#  'A',
#  'R',
#  'E',
#  'N',
#  'T',
#  'S',
#  ',',
#  '1',
#  '7',
#  '0',
#  ',',
#  '1',
#  '7',
#  '1',
#  '\n',
#  '5',
#  '1',
#  ',',
#  'R',
#  'A',
#  'C',
#  'E',
#  '_',
#  'K',
#  ',',
#  '1',
#  '7',
#  '2',
#  ',',
#  '1',
#  '7',
#  '2',
#  '\n',
#  '5',
#  '2',
#  ',',
#  'R',
#  'A',
#  'C',
#  'E',
#  'E',
#  'T',
#  'H',
#  'K',
#  ',',
#  '1',
#  '7',
#  '3',
#  ',',
#  '1',
#  '7',
#  '3',
#  '\n',
#  '5',
#  '3',
#  ',',
#  'R',
#  'E',
#  'N',
#  'T',
#  '_',
#  'O',
#  'W',
#  'N',
#  ',',
#  '1',
#  '7',
#  '4',
#  ',',
#  '1',
#  '7',
#  '5',
#  '\n',
#  '5',
#  '5',
#  ',',
#  'S',
#  'E',
#  'X',
#  ',',
#  '1',
#  '7',
#  '6',
#  ',',
#  '1',
#  '7',
#  '6',
#  '\n',
#  '5',
#  '6',
#  ',',
#  'E',
#  'S',
#  'T',
#  'I',
#  'A',
#  'P',
#  '1',
#  '4',
#  ',',
#  '1',
#  '7',
#  '7',
#  ',',
#  '1',
#  '7',
#  '9',
#  '\n',
#  '5',
#  '7',
#  ',',
#  'E',
#  'S',
#  'T',
#  '_',
#  'G',
#  'R',
#  'A',
#  'N',
#  'T',
#  ',',
#  '1',
#  '8',
#  '0',
#  ',',
#  '1',
#  '8',
#  '1',
#  '\n',
#  '5',
#  '9',
#  ',',
#  'S',
#  'T',
#  'A',
#  'T',
#  'E',
#  ',',
#  '1',
#  '8',
#  '2',
#  ',',
#  '1',
#  '8',
#  '3',
#  '\n',
#  '6',
#  '0',
#  ',',
#  'D',
#  '6',
#  'R',
#  ',',
#  '1',
#  '8',
#  '4',
#  ',',
#  '1',
#  '8',
#  '4',
#  '\n',
#  '6',
#  '2',
#  ',',
#  'D',
#  '7',
#  ',',
#  '1',
#  '8',
#  '5',
#  ',',
#  '1',
#  '8',
#  '5',
#  '\n',
#  '6',
#  '4',
#  ',',
#  'N',
#  '_',
#  'P',
#  'R',
#  'V',
#  'R',
#  ',',
#  '1',
#  '8',
#  '6',
#  ',',
#  '1',
#  '8',
#  '6',
#  '\n',
#  '6',
#  '6',
#  ',',
#  'P',
#  'R',
#  'O',
#  'V',
#  '_',
#  'F',
#  'A',
#  'C',
#  ',',
#  '1',
#  '8',
#  '7',
#  ',',
#  '1',
#  '8',
#  '7',
#  '\n',
#  '6',
#  ...]

# %% [markdown]
# Okay that does NOT look really good...Moving on since this is not part of the assignment deliverables anyways.

# %%
#Let's create a dictionary of the dataframe.
NIS_dict = NIS_dfclean.to_dict('record')

# %%
#By 'record' this is the output:
NIS_dict
# Out:
# [{'Variable Name': 'SEQNUMC', 'Begin': '1', 'End': '6'},
#  {'Variable Name': 'SEQNUMHH', 'Begin': '7', 'End': '11'},
#  {'Variable Name': 'PDAT', 'Begin': '12', 'End': '12'},
#  {'Variable Name': 'PROVWT_D', 'Begin': '13', 'End': '31'},
#  {'Variable Name': 'PROVWT_D_TERR', 'Begin': '32', 'End': '50'},
#  {'Variable Name': 'RDDWT_D', 'Begin': '51', 'End': '69'},
#  {'Variable Name': 'RDDWT_D_TERR', 'Begin': '70', 'End': '88'},
#  {'Variable Name': 'STRATUM', 'Begin': '89', 'End': '92'},
#  {'Variable Name': 'YEAR', 'Begin': '93', 'End': '96'},
#  {'Variable Name': 'AGECPOXR', 'Begin': '97', 'End': '97'},
#  {'Variable Name': 'HAD_CPOX', 'Begin': '98', 'End': '99'},
#  {'Variable Name': 'SHOTCARD', 'Begin': '100', 'End': '100'},
#  {'Variable Name': 'AGEGRP', 'Begin': '101', 'End': '101'},
#  {'Variable Name': 'BF_ENDR06', 'Begin': '102', 'End': '109'},
#  {'Variable Name': 'BF_EXCLR06', 'Begin': '110', 'End': '117'},
#  {'Variable Name': 'BF_FORMR08', 'Begin': '118', 'End': '125'},
#  {'Variable Name': 'BFENDFL06', 'Begin': '126', 'End': '126'},
#  {'Variable Name': 'BFFORMFL06', 'Begin': '127', 'End': '127'},
#  {'Variable Name': 'C1R', 'Begin': '128', 'End': '128'},
#  {'Variable Name': 'C5R', 'Begin': '129', 'End': '130'},
#  {'Variable Name': 'CBF_01', 'Begin': '131', 'End': '132'},
#  {'Variable Name': 'CEN_REG', 'Begin': '133', 'End': '133'},
#  {'Variable Name': 'CHILDNM', 'Begin': '134', 'End': '134'},
#  {'Variable Name': 'CWIC_01', 'Begin': '135', 'End': '136'},
#  {'Variable Name': 'CWIC_02', 'Begin': '137', 'End': '138'},
#  {'Variable Name': 'EDUC1', 'Begin': '139', 'End': '139'},
#  {'Variable Name': 'FRSTBRN', 'Begin': '140', 'End': '140'},
#  {'Variable Name': 'I_HISP_K', 'Begin': '141', 'End': '141'},
#  {'Variable Name': 'INCPORAR', 'Begin': '142', 'End': '157'},
#  {'Variable Name': 'INCPOV1', 'Begin': '158', 'End': '158'},
#  {'Variable Name': 'INCQ298A', 'Begin': '159', 'End': '160'},
#  {'Variable Name': 'INTRP', 'Begin': '161', 'End': '161'},
#  {'Variable Name': 'LANGUAGE', 'Begin': '162', 'End': '162'},
#  {'Variable Name': 'M_AGEGRP', 'Begin': '163', 'End': '163'},
#  {'Variable Name': 'Variable Name', 'Begin': 'Position', 'End': 'Position'},
#  {'Variable Name': 'MARITAL2', 'Begin': '164', 'End': '164'},
#  {'Variable Name': 'MOBIL_I', 'Begin': '165', 'End': '165'},
#  {'Variable Name': 'NUM_PHONE', 'Begin': '166', 'End': '167'},
#  {'Variable Name': 'NUM_CELLS_HH', 'Begin': '168', 'End': '169'},
#  {'Variable Name': 'NUM_CELLS_PARENTS', 'Begin': '170', 'End': '171'},
#  {'Variable Name': 'RACE_K', 'Begin': '172', 'End': '172'},
#  {'Variable Name': 'RACEETHK', 'Begin': '173', 'End': '173'},
#  {'Variable Name': 'RENT_OWN', 'Begin': '174', 'End': '175'},
#  {'Variable Name': 'SEX', 'Begin': '176', 'End': '176'},
#  {'Variable Name': 'ESTIAP14', 'Begin': '177', 'End': '179'},
#  {'Variable Name': 'EST_GRANT', 'Begin': '180', 'End': '181'},
#  {'Variable Name': 'STATE', 'Begin': '182', 'End': '183'},
#  {'Variable Name': 'D6R', 'Begin': '184', 'End': '184'},
#  {'Variable Name': 'D7', 'Begin': '185', 'End': '185'},
#  {'Variable Name': 'N_PRVR', 'Begin': '186', 'End': '186'},
#  {'Variable Name': 'PROV_FAC', 'Begin': '187', 'End': '187'},
#  {'Variable Name': 'REGISTRY', 'Begin': '188', 'End': '188'},
#  {'Variable Name': 'VFC_ORDER', 'Begin': '189', 'End': '189'},
#  {'Variable Name': 'HEP_BRTH', 'Begin': '190', 'End': '190'},
#  {'Variable Name': 'HEP_FLAG', 'Begin': '191', 'End': '191'},
#  {'Variable Name': 'P_NUHEPX', 'Begin': '192', 'End': '192'},
#  {'Variable Name': 'P_NUHIBX', 'Begin': '193', 'End': '193'},
#  {'Variable Name': 'P_NUHPHB', 'Begin': '194', 'End': '194'},
#  {'Variable Name': 'P_NUMDAH', 'Begin': '195', 'End': '195'},
#  {'Variable Name': 'P_NUMDHI', 'Begin': '196', 'End': '196'},
#  {'Variable Name': 'P_NUMDIH', 'Begin': '197', 'End': '197'},
#  {'Variable Name': 'P_NUMDTA', 'Begin': '198', 'End': '198'},
#  {'Variable Name': 'P_NUMDTP', 'Begin': '199', 'End': '199'},
#  {'Variable Name': 'P_NUMFLU', 'Begin': '200', 'End': '200'},
#  {'Variable Name': 'P_NUMFLUL', 'Begin': '201', 'End': '201'},
#  {'Variable Name': 'P_NUMFLUM', 'Begin': '202', 'End': '202'},
#  {'Variable Name': 'P_NUMFLUN', 'Begin': '203', 'End': '203'},
#  {'Variable Name': 'P_NUMHEA', 'Begin': '204', 'End': '204'},
#  {'Variable Name': 'P_NUMHEN', 'Begin': '205', 'End': '205'},
#  {'Variable Name': 'P_NUMHEP', 'Begin': '206', 'End': '206'},
#  {'Variable Name': 'P_NUMHG', 'Begin': '207', 'End': '207'},
#  {'Variable Name': 'P_NUMHHY', 'Begin': '208', 'End': '208'},
#  {'Variable Name': 'P_NUMHIB', 'Begin': '209', 'End': '209'},
#  {'Variable Name': 'P_NUMHIN', 'Begin': '210', 'End': '210'},
#  {'Variable Name': 'P_NUMHION', 'Begin': '211', 'End': '211'},
#  {'Variable Name': 'P_NUMHM', 'Begin': '212', 'End': '212'},
#  {'Variable Name': 'P_NUMHS', 'Begin': '213', 'End': '213'},
#  {'Variable Name': 'P_NUMIPV', 'Begin': '214', 'End': '214'},
#  {'Variable Name': 'P_NUMMCN', 'Begin': '215', 'End': '215'},
#  {'Variable Name': 'P_NUMMMR', 'Begin': '216', 'End': '216'},
#  {'Variable Name': 'P_NUMMMRX', 'Begin': '217', 'End': '217'},
#  {'Variable Name': 'P_NUMMMX', 'Begin': '218', 'End': '218'},
#  {'Variable Name': 'P_NUMMP', 'Begin': '219', 'End': '219'},
#  {'Variable Name': 'P_NUMMPR', 'Begin': '220', 'End': '220'},
#  {'Variable Name': 'P_NUMMRV', 'Begin': '221', 'End': '221'},
#  {'Variable Name': 'P_NUMMS', 'Begin': '222', 'End': '222'},
#  {'Variable Name': 'P_NUMMSM', 'Begin': '223', 'End': '223'},
#  {'Variable Name': 'P_NUMMSR', 'Begin': '224', 'End': '224'},
#  {'Variable Name': 'P_NUMOLN', 'Begin': '225', 'End': '225'},
#  {'Variable Name': 'P_NUMOPV', 'Begin': '226', 'End': '226'},
#  {'Variable Name': 'P_NUMPCV', 'Begin': '227', 'End': '227'},
#  {'Variable Name': 'P_NUMPCP', 'Begin': '228', 'End': '228'},
#  {'Variable Name': 'P_NUMPCC', 'Begin': '229', 'End': '229'},
#  {'Variable Name': 'P_NUMPCC7', 'Begin': '230', 'End': '230'},
#  {'Variable Name': 'P_NUMPCC13', 'Begin': '231', 'End': '231'},
#  {'Variable Name': 'P_NUMPCCN', 'Begin': '232', 'End': '232'},
#  {'Variable Name': 'P_NUMPCN', 'Begin': '233', 'End': '233'},
#  {'Variable Name': 'P_NUMPOL', 'Begin': '234', 'End': '234'},
#  {'Variable Name': 'P_NUMRB', 'Begin': '235', 'End': '235'},
#  {'Variable Name': 'P_NUMRG', 'Begin': '236', 'End': '236'},
#  {'Variable Name': 'P_NUMRM', 'Begin': '237', 'End': '237'},
#  {'Variable Name': 'P_NUMRO', 'Begin': '238', 'End': '238'},
#  {'Variable Name': 'P_NUMROT', 'Begin': '239', 'End': '239'},
#  {'Variable Name': 'P_NUMTPN', 'Begin': '240', 'End': '240'},
#  {'Variable Name': 'P_NUMVRC', 'Begin': '241', 'End': '241'},
#  {'Variable Name': 'P_NUMVRN', 'Begin': '242', 'End': '242'},
#  {'Variable Name': 'P_NUMVRX', 'Begin': '243', 'End': '243'},
#  {'Variable Name': 'P_U12VRC', 'Begin': '244', 'End': '244'},
#  {'Variable Name': 'P_UTD331', 'Begin': '245', 'End': '245'},
#  {'Variable Name': 'P_UTD431', 'Begin': '246', 'End': '246'},
#  {'Variable Name': 'P_UTDHEP', 'Begin': '247', 'End': '247'},
#  {'Variable Name': 'P_UTDHEPA1', 'Begin': '248', 'End': '248'},
#  {'Variable Name': 'P_UTDHEPA2', 'Begin': '249', 'End': '249'},
#  {'Variable Name': 'P_UTDHIB', 'Begin': '250', 'End': '250'},
#  {'Variable Name': 'P_UTDHIB_ROUT_S', 'Begin': '251', 'End': '251'},
#  {'Variable Name': 'P_UTDHIB_SHORT_S', 'Begin': '252', 'End': '252'},
#  {'Variable Name': 'P_UTDMCV', 'Begin': '253', 'End': '253'},
#  {'Variable Name': 'P_UTDMMX', 'Begin': '254', 'End': '254'},
#  {'Variable Name': 'P_UTDPC3', 'Begin': '255', 'End': '255'},
#  {'Variable Name': 'P_UTDPCV', 'Begin': '256', 'End': '256'},
#  {'Variable Name': 'P_UTDPCVB13', 'Begin': '257', 'End': '257'},
#  {'Variable Name': 'P_UTDPOL', 'Begin': '258', 'End': '258'},
#  {'Variable Name': 'P_UTDROT_S', 'Begin': '259', 'End': '259'},
#  {'Variable Name': 'P_UTDTP3', 'Begin': '260', 'End': '260'},
#  {'Variable Name': 'P_UTDTP4', 'Begin': '261', 'End': '261'},
#  {'Variable Name': 'PU431331', 'Begin': '262', 'End': '262'},
#  {'Variable Name': 'P_UTD431H31_ROUT_S', 'Begin': '263', 'End': '263'},
#  {'Variable Name': 'PU431_31', 'Begin': '264', 'End': '264'},
#  {'Variable Name': 'PU4313313', 'Begin': '265', 'End': '265'},
#  {'Variable Name': 'P_UTD431H313_ROUT_S', 'Begin': '266', 'End': '266'},
#  {'Variable Name': 'PU4313314', 'Begin': '267', 'End': '267'},
#  {'Variable Name': 'P_UTD431H314_ROUT_S', 'Begin': '268', 'End': '268'},
#  {'Variable Name': 'PU431_314', 'Begin': '269', 'End': '269'},
#  {'Variable Name': 'PUT43133', 'Begin': '270', 'End': '270'},
#  {'Variable Name': 'P_UTD431H3_ROUT_S', 'Begin': '271', 'End': '271'},
#  {'Variable Name': 'PUTD4313', 'Begin': '272', 'End': '272'},
#  {'Variable Name': 'P_UTD431H_ROUT_S', 'Begin': '273', 'End': '273'},
#  {'Variable Name': 'U1D_HEP', 'Begin': '274', 'End': '274'},
#  {'Variable Name': 'U2D_HEP', 'Begin': '275', 'End': '275'},
#  {'Variable Name': 'U3D_HEP', 'Begin': '276', 'End': '276'},
#  {'Variable Name': 'DDTP1', 'Begin': '277', 'End': '280'},
#  {'Variable Name': 'DDTP2', 'Begin': '281', 'End': '284'},
#  {'Variable Name': 'DDTP3', 'Begin': '285', 'End': '288'},
#  {'Variable Name': 'DDTP4', 'Begin': '289', 'End': '292'},
#  {'Variable Name': 'DDTP5', 'Begin': '293', 'End': '296'},
#  {'Variable Name': 'DDTP6', 'Begin': '297', 'End': '300'},
#  {'Variable Name': 'DDTP7', 'Begin': '301', 'End': '301'},
#  {'Variable Name': 'DDTP8', 'Begin': '302', 'End': '302'},
#  {'Variable Name': 'DDTP9', 'Begin': '303', 'End': '303'},
#  {'Variable Name': 'DFLU1', 'Begin': '304', 'End': '307'},
#  {'Variable Name': 'DFLU2', 'Begin': '308', 'End': '311'},
#  {'Variable Name': 'DFLU3', 'Begin': '312', 'End': '315'},
#  {'Variable Name': 'DFLU4', 'Begin': '316', 'End': '319'},
#  {'Variable Name': 'DFLU5', 'Begin': '320', 'End': '323'},
#  {'Variable Name': 'DFLU6', 'Begin': '324', 'End': '327'},
#  {'Variable Name': 'DFLU7', 'Begin': '328', 'End': '328'},
#  {'Variable Name': 'DFLU8', 'Begin': '329', 'End': '329'},
#  {'Variable Name': 'DFLU9', 'Begin': '330', 'End': '330'},
#  {'Variable Name': 'DHEPA1', 'Begin': '331', 'End': '334'},
#  {'Variable Name': 'DHEPA2', 'Begin': '335', 'End': '338'},
#  {'Variable Name': 'DHEPA3', 'Begin': '339', 'End': '342'},
#  {'Variable Name': 'DHEPA4', 'Begin': '343', 'End': '346'},
#  {'Variable Name': 'DHEPA5', 'Begin': '347', 'End': '347'},
#  {'Variable Name': 'DHEPA6', 'Begin': '348', 'End': '348'},
#  {'Variable Name': 'DHEPA7', 'Begin': '349', 'End': '349'},
#  {'Variable Name': 'DHEPA8', 'Begin': '350', 'End': '350'},
#  {'Variable Name': 'DHEPA9', 'Begin': '351', 'End': '351'},
#  {'Variable Name': 'DHEPB1', 'Begin': '352', 'End': '355'},
#  {'Variable Name': 'DHEPB2', 'Begin': '356', 'End': '359'},
#  {'Variable Name': 'DHEPB3', 'Begin': '360', 'End': '363'},
#  {'Variable Name': 'DHEPB4', 'Begin': '364', 'End': '367'},
#  {'Variable Name': 'DHEPB5', 'Begin': '368', 'End': '371'},
#  {'Variable Name': 'DHEPB6', 'Begin': '372', 'End': '374'},
#  {'Variable Name': 'DHEPB7', 'Begin': '375', 'End': '377'},
#  {'Variable Name': 'DHEPB8', 'Begin': '378', 'End': '378'},
#  {'Variable Name': 'DHEPB9', 'Begin': '379', 'End': '379'},
#  {'Variable Name': 'DHIB1', 'Begin': '380', 'End': '383'},
#  {'Variable Name': 'DHIB2', 'Begin': '384', 'End': '387'},
#  {'Variable Name': 'DHIB3', 'Begin': '388', 'End': '391'},
#  {'Variable Name': 'DHIB4', 'Begin': '392', 'End': '395'},
#  {'Variable Name': 'DHIB5', 'Begin': '396', 'End': '399'},
#  {'Variable Name': 'DHIB6', 'Begin': '400', 'End': '402'},
#  {'Variable Name': 'DHIB7', 'Begin': '403', 'End': '405'},
#  {'Variable Name': 'DHIB8', 'Begin': '406', 'End': '406'},
#  {'Variable Name': 'DHIB9', 'Begin': '407', 'End': '407'},
#  {'Variable Name': 'DMMR1', 'Begin': '408', 'End': '411'},
#  {'Variable Name': 'DMMR2', 'Begin': '412', 'End': '415'},
#  {'Variable Name': 'DMMR3', 'Begin': '416', 'End': '418'},
#  {'Variable Name': 'DMMR4', 'Begin': '419', 'End': '421'},
#  {'Variable Name': 'DMMR5', 'Begin': '422', 'End': '422'},
#  {'Variable Name': 'DMMR6', 'Begin': '423', 'End': '423'},
#  {'Variable Name': 'DMMR7', 'Begin': '424', 'End': '424'},
#  {'Variable Name': 'DMMR8', 'Begin': '425', 'End': '425'},
#  {'Variable Name': 'DMMR9', 'Begin': '426', 'End': '426'},
#  {'Variable Name': 'DMP1', 'Begin': '427', 'End': '427'},
#  {'Variable Name': 'DMP2', 'Begin': '428', 'End': '428'},
#  {'Variable Name': 'DMP3', 'Begin': '429', 'End': '429'},
#  {'Variable Name': 'DMP4', 'Begin': '430', 'End': '430'},
#  {'Variable Name': 'DMP5', 'Begin': '431', 'End': '431'},
#  {'Variable Name': 'DMP6', 'Begin': '432', 'End': '432'},
#  {'Variable Name': 'DMP7', 'Begin': '433', 'End': '433'},
#  {'Variable Name': 'DMP8', 'Begin': '434', 'End': '434'},
#  {'Variable Name': 'DMP9', 'Begin': '435', 'End': '435'},
#  {'Variable Name': 'DMPRB1', 'Begin': '436', 'End': '438'},
#  {'Variable Name': 'DMPRB2', 'Begin': '439', 'End': '439'},
#  {'Variable Name': 'DMPRB3', 'Begin': '440', 'End': '440'},
#  {'Variable Name': 'DMPRB4', 'Begin': '441', 'End': '441'},
#  {'Variable Name': 'DMPRB5', 'Begin': '442', 'End': '442'},
#  {'Variable Name': 'DMPRB6', 'Begin': '443', 'End': '443'},
#  {'Variable Name': 'DMPRB7', 'Begin': '444', 'End': '444'},
#  {'Variable Name': 'DMPRB8', 'Begin': '445', 'End': '445'},
#  {'Variable Name': 'DMPRB9', 'Begin': '446', 'End': '446'},
#  {'Variable Name': 'DPCV1', 'Begin': '447', 'End': '450'},
#  {'Variable Name': 'DPCV2', 'Begin': '451', 'End': '454'},
#  {'Variable Name': 'DPCV3', 'Begin': '455', 'End': '458'},
#  {'Variable Name': 'DPCV4', 'Begin': '459', 'End': '462'},
#  {'Variable Name': 'DPCV5', 'Begin': '463', 'End': '466'},
#  {'Variable Name': 'DPCV6', 'Begin': '467', 'End': '469'},
#  {'Variable Name': 'DPCV7', 'Begin': '470', 'End': '472'},
#  {'Variable Name': 'DPCV8', 'Begin': '473', 'End': '473'},
#  {'Variable Name': 'DPCV9', 'Begin': '474', 'End': '474'},
#  {'Variable Name': 'DPOLIO1', 'Begin': '475', 'End': '478'},
#  {'Variable Name': 'DPOLIO2', 'Begin': '479', 'End': '482'},
#  {'Variable Name': 'DPOLIO3', 'Begin': '483', 'End': '486'},
#  {'Variable Name': 'DPOLIO4', 'Begin': '487', 'End': '490'},
#  {'Variable Name': 'DPOLIO5', 'Begin': '491', 'End': '493'},
#  {'Variable Name': 'DPOLIO6', 'Begin': '494', 'End': '496'},
#  {'Variable Name': 'DPOLIO7', 'Begin': '497', 'End': '497'},
#  {'Variable Name': 'DPOLIO8', 'Begin': '498', 'End': '498'},
#  {'Variable Name': 'DPOLIO9', 'Begin': '499', 'End': '499'},
#  {'Variable Name': 'DRB1', 'Begin': '500', 'End': '502'},
#  {'Variable Name': 'DRB2', 'Begin': '503', 'End': '503'},
#  {'Variable Name': 'DRB3', 'Begin': '504', 'End': '504'},
#  {'Variable Name': 'DRB4', 'Begin': '505', 'End': '505'},
#  {'Variable Name': 'DRB5', 'Begin': '506', 'End': '506'},
#  {'Variable Name': 'DRB6', 'Begin': '507', 'End': '507'},
#  {'Variable Name': 'DRB7', 'Begin': '508', 'End': '508'},
#  {'Variable Name': 'DRB8', 'Begin': '509', 'End': '509'},
#  {'Variable Name': 'DRB9', 'Begin': '510', 'End': '510'},
#  {'Variable Name': 'DROT1', 'Begin': '511', 'End': '513'},
#  {'Variable Name': 'DROT2', 'Begin': '514', 'End': '516'},
#  {'Variable Name': 'DROT3', 'Begin': '517', 'End': '520'},
#  {'Variable Name': 'DROT4', 'Begin': '521', 'End': '523'},
#  {'Variable Name': 'DROT5', 'Begin': '524', 'End': '526'},
#  {'Variable Name': 'DROT6', 'Begin': '527', 'End': '527'},
#  {'Variable Name': 'DROT7', 'Begin': '528', 'End': '528'},
#  {'Variable Name': 'DROT8', 'Begin': '529', 'End': '529'},
#  {'Variable Name': 'DROT9', 'Begin': '530', 'End': '530'},
#  {'Variable Name': 'DVRC1', 'Begin': '531', 'End': '534'},
#  {'Variable Name': 'DVRC2', 'Begin': '535', 'End': '538'},
#  {'Variable Name': 'DVRC3', 'Begin': '539', 'End': '542'},
#  {'Variable Name': 'DVRC4', 'Begin': '543', 'End': '543'},
#  {'Variable Name': 'DVRC5', 'Begin': '544', 'End': '544'},
#  {'Variable Name': 'DVRC6', 'Begin': '545', 'End': '545'},
#  {'Variable Name': 'DVRC7', 'Begin': '546', 'End': '546'},
#  {'Variable Name': 'DVRC8', 'Begin': '547', 'End': '547'},
#  {'Variable Name': 'DVRC9', 'Begin': '548', 'End': '548'},
#  {'Variable Name': 'DTP1_AGE', 'Begin': '549', 'End': '550'},
#  {'Variable Name': 'DTP2_AGE', 'Begin': '551', 'End': '552'},
#  {'Variable Name': 'DTP3_AGE', 'Begin': '553', 'End': '554'},
#  {'Variable Name': 'DTP4_AGE', 'Begin': '555', 'End': '556'},
#  {'Variable Name': 'DTP5_AGE', 'Begin': '557', 'End': '558'},
#  {'Variable Name': 'DTP6_AGE', 'Begin': '559', 'End': '560'},
#  {'Variable Name': 'DTP7_AGE', 'Begin': '561', 'End': '561'},
#  {'Variable Name': 'DTP8_AGE', 'Begin': '562', 'End': '562'},
#  {'Variable Name': 'DTP9_AGE', 'Begin': '563', 'End': '563'},
#  {'Variable Name': 'FLU1_AGE', 'Begin': '564', 'End': '565'},
#  {'Variable Name': 'FLU2_AGE', 'Begin': '566', 'End': '567'},
#  {'Variable Name': 'FLU3_AGE', 'Begin': '568', 'End': '569'},
#  {'Variable Name': 'FLU4_AGE', 'Begin': '570', 'End': '571'},
#  {'Variable Name': 'FLU5_AGE', 'Begin': '572', 'End': '573'},
#  {'Variable Name': 'FLU6_AGE', 'Begin': '574', 'End': '575'},
#  {'Variable Name': 'FLU7_AGE', 'Begin': '576', 'End': '576'},
#  {'Variable Name': 'FLU8_AGE', 'Begin': '577', 'End': '577'},
#  {'Variable Name': 'FLU9_AGE', 'Begin': '578', 'End': '578'},
#  {'Variable Name': 'HEA1_AGE', 'Begin': '579', 'End': '580'},
#  {'Variable Name': 'HEA2_AGE', 'Begin': '581', 'End': '582'},
#  {'Variable Name': 'HEA3_AGE', 'Begin': '583', 'End': '584'},
#  {'Variable Name': 'HEA4_AGE', 'Begin': '585', 'End': '586'},
#  {'Variable Name': 'HEA5_AGE', 'Begin': '587', 'End': '587'},
#  {'Variable Name': 'HEA6_AGE', 'Begin': '588', 'End': '588'},
#  {'Variable Name': 'HEA7_AGE', 'Begin': '589', 'End': '589'},
#  {'Variable Name': 'HEA8_AGE', 'Begin': '590', 'End': '590'},
#  {'Variable Name': 'HEA9_AGE', 'Begin': '591', 'End': '591'},
#  {'Variable Name': 'HEP1_AGE', 'Begin': '592', 'End': '593'},
#  {'Variable Name': 'HEP2_AGE', 'Begin': '594', 'End': '595'},
#  {'Variable Name': 'HEP3_AGE', 'Begin': '596', 'End': '597'},
#  {'Variable Name': 'HEP4_AGE', 'Begin': '598', 'End': '599'},
#  {'Variable Name': 'HEP5_AGE', 'Begin': '600', 'End': '601'},
#  {'Variable Name': 'HEP6_AGE', 'Begin': '602', 'End': '603'},
#  {'Variable Name': 'HEP7_AGE', 'Begin': '604', 'End': '605'},
#  {'Variable Name': 'HEP8_AGE', 'Begin': '606', 'End': '606'},
#  {'Variable Name': 'HEP9_AGE', 'Begin': '607', 'End': '607'},
#  {'Variable Name': 'HIB1_AGE', 'Begin': '608', 'End': '609'},
#  {'Variable Name': 'HIB2_AGE', 'Begin': '610', 'End': '611'},
#  {'Variable Name': 'HIB3_AGE', 'Begin': '612', 'End': '613'},
#  {'Variable Name': 'HIB4_AGE', 'Begin': '614', 'End': '615'},
#  {'Variable Name': 'HIB5_AGE', 'Begin': '616', 'End': '617'},
#  {'Variable Name': 'HIB6_AGE', 'Begin': '618', 'End': '619'},
#  {'Variable Name': 'HIB7_AGE', 'Begin': '620', 'End': '621'},
#  {'Variable Name': 'HIB8_AGE', 'Begin': '622', 'End': '622'},
#  {'Variable Name': 'HIB9_AGE', 'Begin': '623', 'End': '623'},
#  {'Variable Name': 'MMR1_AGE', 'Begin': '624', 'End': '625'},
#  {'Variable Name': 'MMR2_AGE', 'Begin': '626', 'End': '627'},
#  {'Variable Name': 'MMR3_AGE', 'Begin': '628', 'End': '629'},
#  {'Variable Name': 'MMR4_AGE', 'Begin': '630', 'End': '631'},
#  {'Variable Name': 'MMR5_AGE', 'Begin': '632', 'End': '632'},
#  {'Variable Name': 'MMR6_AGE', 'Begin': '633', 'End': '633'},
#  {'Variable Name': 'MMR7_AGE', 'Begin': '634', 'End': '634'},
#  {'Variable Name': 'MMR8_AGE', 'Begin': '635', 'End': '635'},
#  {'Variable Name': 'MMR9_AGE', 'Begin': '636', 'End': '636'},
#  {'Variable Name': 'MP1_AGE', 'Begin': '637', 'End': '637'},
#  {'Variable Name': 'MP2_AGE', 'Begin': '638', 'End': '638'},
#  {'Variable Name': 'MP3_AGE', 'Begin': '639', 'End': '639'},
#  {'Variable Name': 'MP4_AGE', 'Begin': '640', 'End': '640'},
#  {'Variable Name': 'MP5_AGE', 'Begin': '641', 'End': '641'},
#  {'Variable Name': 'MP6_AGE', 'Begin': '642', 'End': '642'},
#  {'Variable Name': 'MP7_AGE', 'Begin': '643', 'End': '643'},
#  {'Variable Name': 'MP8_AGE', 'Begin': '644', 'End': '644'},
#  {'Variable Name': 'MP9_AGE', 'Begin': '645', 'End': '645'},
#  {'Variable Name': 'MPR1_AGE', 'Begin': '646', 'End': '646'},
#  {'Variable Name': 'MPR2_AGE', 'Begin': '647', 'End': '647'},
#  {'Variable Name': 'MPR3_AGE', 'Begin': '648', 'End': '648'},
#  {'Variable Name': 'MPR4_AGE', 'Begin': '649', 'End': '649'},
#  {'Variable Name': 'MPR5_AGE', 'Begin': '650', 'End': '650'},
#  {'Variable Name': 'MPR6_AGE', 'Begin': '651', 'End': '651'},
#  {'Variable Name': 'MPR7_AGE', 'Begin': '652', 'End': '652'},
#  {'Variable Name': 'MPR8_AGE', 'Begin': '653', 'End': '653'},
#  {'Variable Name': 'MPR9_AGE', 'Begin': '654', 'End': '654'},
#  {'Variable Name': 'PCV1_AGE', 'Begin': '655', 'End': '656'},
#  {'Variable Name': 'PCV2_AGE', 'Begin': '657', 'End': '658'},
#  {'Variable Name': 'PCV3_AGE', 'Begin': '659', 'End': '660'},
#  {'Variable Name': 'PCV4_AGE', 'Begin': '661', 'End': '662'},
#  {'Variable Name': 'PCV5_AGE', 'Begin': '663', 'End': '664'},
#  {'Variable Name': 'PCV6_AGE', 'Begin': '665', 'End': '666'},
#  {'Variable Name': 'PCV7_AGE', 'Begin': '667', 'End': '668'},
#  {'Variable Name': 'PCV8_AGE', 'Begin': '669', 'End': '669'},
#  {'Variable Name': 'PCV9_AGE', 'Begin': '670', 'End': '670'},
#  {'Variable Name': 'POL1_AGE', 'Begin': '671', 'End': '672'},
#  {'Variable Name': 'POL2_AGE', 'Begin': '673', 'End': '674'},
#  {'Variable Name': 'POL3_AGE', 'Begin': '675', 'End': '676'},
#  {'Variable Name': 'POL4_AGE', 'Begin': '677', 'End': '678'},
#  {'Variable Name': 'POL5_AGE', 'Begin': '679', 'End': '680'},
#  {'Variable Name': 'POL6_AGE', 'Begin': '681', 'End': '682'},
#  {'Variable Name': 'POL7_AGE', 'Begin': '683', 'End': '683'},
#  {'Variable Name': 'POL8_AGE', 'Begin': '684', 'End': '684'},
#  {'Variable Name': 'POL9_AGE', 'Begin': '685', 'End': '685'},
#  {'Variable Name': 'RB1_AGE', 'Begin': '686', 'End': '687'},
#  {'Variable Name': 'RB2_AGE', 'Begin': '688', 'End': '688'},
#  {'Variable Name': 'RB3_AGE', 'Begin': '689', 'End': '689'},
#  {'Variable Name': 'RB4_AGE', 'Begin': '690', 'End': '690'},
#  {'Variable Name': 'RB5_AGE', 'Begin': '691', 'End': '691'},
#  {'Variable Name': 'RB6_AGE', 'Begin': '692', 'End': '692'},
#  {'Variable Name': 'RB7_AGE', 'Begin': '693', 'End': '693'},
#  {'Variable Name': 'RB8_AGE', 'Begin': '694', 'End': '694'},
#  {'Variable Name': 'RB9_AGE', 'Begin': '695', 'End': '695'},
#  {'Variable Name': 'ROT1_AGE', 'Begin': '696', 'End': '697'},
#  {'Variable Name': 'ROT2_AGE', 'Begin': '698', 'End': '699'},
#  {'Variable Name': 'ROT3_AGE', 'Begin': '700', 'End': '701'},
#  {'Variable Name': 'ROT4_AGE', 'Begin': '702', 'End': '703'},
#  {'Variable Name': 'ROT5_AGE', 'Begin': '704', 'End': '704'},
#  {'Variable Name': 'ROT6_AGE', 'Begin': '705', 'End': '705'},
#  {'Variable Name': 'ROT7_AGE', 'Begin': '706', 'End': '706'},
#  {'Variable Name': 'ROT8_AGE', 'Begin': '707', 'End': '707'},
#  {'Variable Name': 'ROT9_AGE', 'Begin': '708', 'End': '708'},
#  {'Variable Name': 'VRC1_AGE', 'Begin': '709', 'End': '710'},
#  {'Variable Name': 'VRC2_AGE', 'Begin': '711', 'End': '712'},
#  {'Variable Name': 'VRC3_AGE', 'Begin': '713', 'End': '714'},
#  {'Variable Name': 'VRC4_AGE', 'Begin': '715', 'End': '715'},
#  {'Variable Name': 'VRC5_AGE', 'Begin': '716', 'End': '716'},
#  {'Variable Name': 'VRC6_AGE', 'Begin': '717', 'End': '717'},
#  {'Variable Name': 'VRC7_AGE', 'Begin': '718', 'End': '718'},
#  {'Variable Name': 'VRC8_AGE', 'Begin': '719', 'End': '719'},
#  {'Variable Name': 'VRC9_AGE', 'Begin': '720', 'End': '720'},
#  {'Variable Name': 'XDTPTY1', 'Begin': '721', 'End': '722'},
#  {'Variable Name': 'XDTPTY2', 'Begin': '723', 'End': '724'},
#  {'Variable Name': 'XDTPTY3', 'Begin': '725', 'End': '726'},
#  {'Variable Name': 'XDTPTY4', 'Begin': '727', 'End': '728'},
#  {'Variable Name': 'XDTPTY5', 'Begin': '729', 'End': '730'},
#  {'Variable Name': 'XDTPTY6', 'Begin': '731', 'End': '732'},
#  {'Variable Name': 'XDTPTY7', 'Begin': '733', 'End': '733'},
#  {'Variable Name': 'XDTPTY8', 'Begin': '734', 'End': '734'},
#  {'Variable Name': 'XDTPTY9', 'Begin': '735', 'End': '735'},
#  {'Variable Name': 'XFLUTY1', 'Begin': '736', 'End': '737'},
#  {'Variable Name': 'XFLUTY2', 'Begin': '738', 'End': '739'},
#  {'Variable Name': 'XFLUTY3', 'Begin': '740', 'End': '741'},
#  {'Variable Name': 'XFLUTY4', 'Begin': '742', 'End': '743'},
#  {'Variable Name': 'XFLUTY5', 'Begin': '744', 'End': '745'},
#  {'Variable Name': 'XFLUTY6', 'Begin': '746', 'End': '747'},
#  {'Variable Name': 'XFLUTY7', 'Begin': '748', 'End': '748'},
#  {'Variable Name': 'XFLUTY8', 'Begin': '749', 'End': '749'},
#  {'Variable Name': 'XFLUTY9', 'Begin': '750', 'End': '750'},
#  {'Variable Name': 'XHEPTY1', 'Begin': '751', 'End': '752'},
#  {'Variable Name': 'XHEPTY2', 'Begin': '753', 'End': '754'},
#  {'Variable Name': 'XHEPTY3', 'Begin': '755', 'End': '756'},
#  {'Variable Name': 'XHEPTY4', 'Begin': '757', 'End': '758'},
#  {'Variable Name': 'XHEPTY5', 'Begin': '759', 'End': '760'},
#  {'Variable Name': 'XHEPTY6', 'Begin': '761', 'End': '762'},
#  {'Variable Name': 'XHEPTY7', 'Begin': '763', 'End': '764'},
#  {'Variable Name': 'XHEPTY8', 'Begin': '765', 'End': '765'},
#  {'Variable Name': 'XHEPTY9', 'Begin': '766', 'End': '766'},
#  {'Variable Name': 'XHIBTY1', 'Begin': '767', 'End': '768'},
#  {'Variable Name': 'XHIBTY2', 'Begin': '769', 'End': '770'},
#  {'Variable Name': 'XHIBTY3', 'Begin': '771', 'End': '772'},
#  {'Variable Name': 'XHIBTY4', 'Begin': '773', 'End': '774'},
#  {'Variable Name': 'XHIBTY5', 'Begin': '775', 'End': '776'},
#  {'Variable Name': 'XHIBTY6', 'Begin': '777', 'End': '778'},
#  {'Variable Name': 'XHIBTY7', 'Begin': '779', 'End': '780'},
#  {'Variable Name': 'XHIBTY8', 'Begin': '781', 'End': '781'},
#  {'Variable Name': 'XHIBTY9', 'Begin': '782', 'End': '782'},
#  {'Variable Name': 'XMMRTY1', 'Begin': '783', 'End': '784'},
#  {'Variable Name': 'XMMRTY2', 'Begin': '785', 'End': '786'},
#  {'Variable Name': 'XMMRTY3', 'Begin': '787', 'End': '788'},
#  {'Variable Name': 'XMMRTY4', 'Begin': '789', 'End': '790'},
#  {'Variable Name': 'XMMRTY5', 'Begin': '791', 'End': '791'},
#  {'Variable Name': 'XMMRTY6', 'Begin': '792', 'End': '792'},
#  {'Variable Name': 'XMMRTY7', 'Begin': '793', 'End': '793'},
#  {'Variable Name': 'XMMRTY8', 'Begin': '794', 'End': '794'},
#  {'Variable Name': 'XMMRTY9', 'Begin': '795', 'End': '795'},
#  {'Variable Name': 'XPCVTY1', 'Begin': '796', 'End': '797'},
#  {'Variable Name': 'XPCVTY2', 'Begin': '798', 'End': '799'},
#  {'Variable Name': 'XPCVTY3', 'Begin': '800', 'End': '801'},
#  {'Variable Name': 'XPCVTY4', 'Begin': '802', 'End': '803'},
#  {'Variable Name': 'XPCVTY5', 'Begin': '804', 'End': '805'},
#  {'Variable Name': 'XPCVTY6', 'Begin': '806', 'End': '807'},
#  {'Variable Name': 'XPCVTY7', 'Begin': '808', 'End': '809'},
#  {'Variable Name': 'XPCVTY8', 'Begin': '810', 'End': '810'},
#  {'Variable Name': 'XPCVTY9', 'Begin': '811', 'End': '811'},
#  {'Variable Name': 'XPOLTY1', 'Begin': '812', 'End': '813'},
#  {'Variable Name': 'XPOLTY2', 'Begin': '814', 'End': '815'},
#  {'Variable Name': 'XPOLTY3', 'Begin': '816', 'End': '817'},
#  {'Variable Name': 'XPOLTY4', 'Begin': '818', 'End': '819'},
#  {'Variable Name': 'XPOLTY5', 'Begin': '820', 'End': '821'},
#  {'Variable Name': 'XPOLTY6', 'Begin': '822', 'End': '823'},
#  {'Variable Name': 'XPOLTY7', 'Begin': '824', 'End': '824'},
#  {'Variable Name': 'XPOLTY8', 'Begin': '825', 'End': '825'},
#  {'Variable Name': 'XPOLTY9', 'Begin': '826', 'End': '826'},
#  {'Variable Name': 'XROTTY1', 'Begin': '827', 'End': '828'},
#  {'Variable Name': 'XROTTY2', 'Begin': '829', 'End': '830'},
#  {'Variable Name': 'XROTTY3', 'Begin': '831', 'End': '832'},
#  {'Variable Name': 'XROTTY4', 'Begin': '833', 'End': '834'},
#  {'Variable Name': 'XROTTY5', 'Begin': '835', 'End': '836'},
#  {'Variable Name': 'XROTTY6', 'Begin': '837', 'End': '837'},
#  {'Variable Name': 'XROTTY7', 'Begin': '838', 'End': '838'},
#  {'Variable Name': 'XROTTY8', 'Begin': '839', 'End': '839'},
#  {'Variable Name': 'XROTTY9', 'Begin': '840', 'End': '840'},
#  {'Variable Name': 'XVRCTY1', 'Begin': '841', 'End': '842'},
#  {'Variable Name': 'XVRCTY2', 'Begin': '843', 'End': '844'},
#  {'Variable Name': 'XVRCTY3', 'Begin': '845', 'End': '846'},
#  {'Variable Name': 'XVRCTY4', 'Begin': '847', 'End': '847'},
#  {'Variable Name': 'XVRCTY5', 'Begin': '848', 'End': '848'},
#  {'Variable Name': 'XVRCTY6', 'Begin': '849', 'End': '849'},
#  {'Variable Name': 'XVRCTY7', 'Begin': '850', 'End': '850'},
#  {'Variable Name': 'XVRCTY8', 'Begin': '851', 'End': '851'},
#  {'Variable Name': 'XVRCTY9', 'Begin': '852', 'End': '852'},
#  {'Variable Name': 'INS_1', 'Begin': '853', 'End': '854'},
#  {'Variable Name': 'INS_2', 'Begin': '855', 'End': '856'},
#  {'Variable Name': 'INS_3', 'Begin': '857', 'End': '858'},
#  {'Variable Name': 'INS_3A', 'Begin': '859', 'End': '860'},
#  {'Variable Name': 'INS_4_5', 'Begin': '861', 'End': '862'},
#  {'Variable Name': 'INS_6', 'Begin': '863', 'End': '864'},
#  {'Variable Name': 'INS_11', 'Begin': '865', 'End': '866'}]

# %%
type(NIS_dict)
# Out:
# list

# %% [markdown]
# The dictionary is a list and NOT what we need. So let's try something else....

# %%
#INDEX set to 'Variable Name' column
NIS_dict1 = NIS_dfclean.set_index("Variable Name").T.to_dict('list')

# %%
#Print the new dictionary now...
NIS_dict1
# Out:
# {'SEQNUMC': ['1', '6'],
#  'SEQNUMHH': ['7', '11'],
#  'PDAT': ['12', '12'],
#  'PROVWT_D': ['13', '31'],
#  'PROVWT_D_TERR': ['32', '50'],
#  'RDDWT_D': ['51', '69'],
#  'RDDWT_D_TERR': ['70', '88'],
#  'STRATUM': ['89', '92'],
#  'YEAR': ['93', '96'],
#  'AGECPOXR': ['97', '97'],
#  'HAD_CPOX': ['98', '99'],
#  'SHOTCARD': ['100', '100'],
#  'AGEGRP': ['101', '101'],
#  'BF_ENDR06': ['102', '109'],
#  'BF_EXCLR06': ['110', '117'],
#  'BF_FORMR08': ['118', '125'],
#  'BFENDFL06': ['126', '126'],
#  'BFFORMFL06': ['127', '127'],
#  'C1R': ['128', '128'],
#  'C5R': ['129', '130'],
#  'CBF_01': ['131', '132'],
#  'CEN_REG': ['133', '133'],
#  'CHILDNM': ['134', '134'],
#  'CWIC_01': ['135', '136'],
#  'CWIC_02': ['137', '138'],
#  'EDUC1': ['139', '139'],
#  'FRSTBRN': ['140', '140'],
#  'I_HISP_K': ['141', '141'],
#  'INCPORAR': ['142', '157'],
#  'INCPOV1': ['158', '158'],
#  'INCQ298A': ['159', '160'],
#  'INTRP': ['161', '161'],
#  'LANGUAGE': ['162', '162'],
#  'M_AGEGRP': ['163', '163'],
#  'Variable Name': ['Position', 'Position'],
#  'MARITAL2': ['164', '164'],
#  'MOBIL_I': ['165', '165'],
#  'NUM_PHONE': ['166', '167'],
#  'NUM_CELLS_HH': ['168', '169'],
#  'NUM_CELLS_PARENTS': ['170', '171'],
#  'RACE_K': ['172', '172'],
#  'RACEETHK': ['173', '173'],
#  'RENT_OWN': ['174', '175'],
#  'SEX': ['176', '176'],
#  'ESTIAP14': ['177', '179'],
#  'EST_GRANT': ['180', '181'],
#  'STATE': ['182', '183'],
#  'D6R': ['184', '184'],
#  'D7': ['185', '185'],
#  'N_PRVR': ['186', '186'],
#  'PROV_FAC': ['187', '187'],
#  'REGISTRY': ['188', '188'],
#  'VFC_ORDER': ['189', '189'],
#  'HEP_BRTH': ['190', '190'],
#  'HEP_FLAG': ['191', '191'],
#  'P_NUHEPX': ['192', '192'],
#  'P_NUHIBX': ['193', '193'],
#  'P_NUHPHB': ['194', '194'],
#  'P_NUMDAH': ['195', '195'],
#  'P_NUMDHI': ['196', '196'],
#  'P_NUMDIH': ['197', '197'],
#  'P_NUMDTA': ['198', '198'],
#  'P_NUMDTP': ['199', '199'],
#  'P_NUMFLU': ['200', '200'],
#  'P_NUMFLUL': ['201', '201'],
#  'P_NUMFLUM': ['202', '202'],
#  'P_NUMFLUN': ['203', '203'],
#  'P_NUMHEA': ['204', '204'],
#  'P_NUMHEN': ['205', '205'],
#  'P_NUMHEP': ['206', '206'],
#  'P_NUMHG': ['207', '207'],
#  'P_NUMHHY': ['208', '208'],
#  'P_NUMHIB': ['209', '209'],
#  'P_NUMHIN': ['210', '210'],
#  'P_NUMHION': ['211', '211'],
#  'P_NUMHM': ['212', '212'],
#  'P_NUMHS': ['213', '213'],
#  'P_NUMIPV': ['214', '214'],
#  'P_NUMMCN': ['215', '215'],
#  'P_NUMMMR': ['216', '216'],
#  'P_NUMMMRX': ['217', '217'],
#  'P_NUMMMX': ['218', '218'],
#  'P_NUMMP': ['219', '219'],
#  'P_NUMMPR': ['220', '220'],
#  'P_NUMMRV': ['221', '221'],
#  'P_NUMMS': ['222', '222'],
#  'P_NUMMSM': ['223', '223'],
#  'P_NUMMSR': ['224', '224'],
#  'P_NUMOLN': ['225', '225'],
#  'P_NUMOPV': ['226', '226'],
#  'P_NUMPCV': ['227', '227'],
#  'P_NUMPCP': ['228', '228'],
#  'P_NUMPCC': ['229', '229'],
#  'P_NUMPCC7': ['230', '230'],
#  'P_NUMPCC13': ['231', '231'],
#  'P_NUMPCCN': ['232', '232'],
#  'P_NUMPCN': ['233', '233'],
#  'P_NUMPOL': ['234', '234'],
#  'P_NUMRB': ['235', '235'],
#  'P_NUMRG': ['236', '236'],
#  'P_NUMRM': ['237', '237'],
#  'P_NUMRO': ['238', '238'],
#  'P_NUMROT': ['239', '239'],
#  'P_NUMTPN': ['240', '240'],
#  'P_NUMVRC': ['241', '241'],
#  'P_NUMVRN': ['242', '242'],
#  'P_NUMVRX': ['243', '243'],
#  'P_U12VRC': ['244', '244'],
#  'P_UTD331': ['245', '245'],
#  'P_UTD431': ['246', '246'],
#  'P_UTDHEP': ['247', '247'],
#  'P_UTDHEPA1': ['248', '248'],
#  'P_UTDHEPA2': ['249', '249'],
#  'P_UTDHIB': ['250', '250'],
#  'P_UTDHIB_ROUT_S': ['251', '251'],
#  'P_UTDHIB_SHORT_S': ['252', '252'],
#  'P_UTDMCV': ['253', '253'],
#  'P_UTDMMX': ['254', '254'],
#  'P_UTDPC3': ['255', '255'],
#  'P_UTDPCV': ['256', '256'],
#  'P_UTDPCVB13': ['257', '257'],
#  'P_UTDPOL': ['258', '258'],
#  'P_UTDROT_S': ['259', '259'],
#  'P_UTDTP3': ['260', '260'],
#  'P_UTDTP4': ['261', '261'],
#  'PU431331': ['262', '262'],
#  'P_UTD431H31_ROUT_S': ['263', '263'],
#  'PU431_31': ['264', '264'],
#  'PU4313313': ['265', '265'],
#  'P_UTD431H313_ROUT_S': ['266', '266'],
#  'PU4313314': ['267', '267'],
#  'P_UTD431H314_ROUT_S': ['268', '268'],
#  'PU431_314': ['269', '269'],
#  'PUT43133': ['270', '270'],
#  'P_UTD431H3_ROUT_S': ['271', '271'],
#  'PUTD4313': ['272', '272'],
#  'P_UTD431H_ROUT_S': ['273', '273'],
#  'U1D_HEP': ['274', '274'],
#  'U2D_HEP': ['275', '275'],
#  'U3D_HEP': ['276', '276'],
#  'DDTP1': ['277', '280'],
#  'DDTP2': ['281', '284'],
#  'DDTP3': ['285', '288'],
#  'DDTP4': ['289', '292'],
#  'DDTP5': ['293', '296'],
#  'DDTP6': ['297', '300'],
#  'DDTP7': ['301', '301'],
#  'DDTP8': ['302', '302'],
#  'DDTP9': ['303', '303'],
#  'DFLU1': ['304', '307'],
#  'DFLU2': ['308', '311'],
#  'DFLU3': ['312', '315'],
#  'DFLU4': ['316', '319'],
#  'DFLU5': ['320', '323'],
#  'DFLU6': ['324', '327'],
#  'DFLU7': ['328', '328'],
#  'DFLU8': ['329', '329'],
#  'DFLU9': ['330', '330'],
#  'DHEPA1': ['331', '334'],
#  'DHEPA2': ['335', '338'],
#  'DHEPA3': ['339', '342'],
#  'DHEPA4': ['343', '346'],
#  'DHEPA5': ['347', '347'],
#  'DHEPA6': ['348', '348'],
#  'DHEPA7': ['349', '349'],
#  'DHEPA8': ['350', '350'],
#  'DHEPA9': ['351', '351'],
#  'DHEPB1': ['352', '355'],
#  'DHEPB2': ['356', '359'],
#  'DHEPB3': ['360', '363'],
#  'DHEPB4': ['364', '367'],
#  'DHEPB5': ['368', '371'],
#  'DHEPB6': ['372', '374'],
#  'DHEPB7': ['375', '377'],
#  'DHEPB8': ['378', '378'],
#  'DHEPB9': ['379', '379'],
#  'DHIB1': ['380', '383'],
#  'DHIB2': ['384', '387'],
#  'DHIB3': ['388', '391'],
#  'DHIB4': ['392', '395'],
#  'DHIB5': ['396', '399'],
#  'DHIB6': ['400', '402'],
#  'DHIB7': ['403', '405'],
#  'DHIB8': ['406', '406'],
#  'DHIB9': ['407', '407'],
#  'DMMR1': ['408', '411'],
#  'DMMR2': ['412', '415'],
#  'DMMR3': ['416', '418'],
#  'DMMR4': ['419', '421'],
#  'DMMR5': ['422', '422'],
#  'DMMR6': ['423', '423'],
#  'DMMR7': ['424', '424'],
#  'DMMR8': ['425', '425'],
#  'DMMR9': ['426', '426'],
#  'DMP1': ['427', '427'],
#  'DMP2': ['428', '428'],
#  'DMP3': ['429', '429'],
#  'DMP4': ['430', '430'],
#  'DMP5': ['431', '431'],
#  'DMP6': ['432', '432'],
#  'DMP7': ['433', '433'],
#  'DMP8': ['434', '434'],
#  'DMP9': ['435', '435'],
#  'DMPRB1': ['436', '438'],
#  'DMPRB2': ['439', '439'],
#  'DMPRB3': ['440', '440'],
#  'DMPRB4': ['441', '441'],
#  'DMPRB5': ['442', '442'],
#  'DMPRB6': ['443', '443'],
#  'DMPRB7': ['444', '444'],
#  'DMPRB8': ['445', '445'],
#  'DMPRB9': ['446', '446'],
#  'DPCV1': ['447', '450'],
#  'DPCV2': ['451', '454'],
#  'DPCV3': ['455', '458'],
#  'DPCV4': ['459', '462'],
#  'DPCV5': ['463', '466'],
#  'DPCV6': ['467', '469'],
#  'DPCV7': ['470', '472'],
#  'DPCV8': ['473', '473'],
#  'DPCV9': ['474', '474'],
#  'DPOLIO1': ['475', '478'],
#  'DPOLIO2': ['479', '482'],
#  'DPOLIO3': ['483', '486'],
#  'DPOLIO4': ['487', '490'],
#  'DPOLIO5': ['491', '493'],
#  'DPOLIO6': ['494', '496'],
#  'DPOLIO7': ['497', '497'],
#  'DPOLIO8': ['498', '498'],
#  'DPOLIO9': ['499', '499'],
#  'DRB1': ['500', '502'],
#  'DRB2': ['503', '503'],
#  'DRB3': ['504', '504'],
#  'DRB4': ['505', '505'],
#  'DRB5': ['506', '506'],
#  'DRB6': ['507', '507'],
#  'DRB7': ['508', '508'],
#  'DRB8': ['509', '509'],
#  'DRB9': ['510', '510'],
#  'DROT1': ['511', '513'],
#  'DROT2': ['514', '516'],
#  'DROT3': ['517', '520'],
#  'DROT4': ['521', '523'],
#  'DROT5': ['524', '526'],
#  'DROT6': ['527', '527'],
#  'DROT7': ['528', '528'],
#  'DROT8': ['529', '529'],
#  'DROT9': ['530', '530'],
#  'DVRC1': ['531', '534'],
#  'DVRC2': ['535', '538'],
#  'DVRC3': ['539', '542'],
#  'DVRC4': ['543', '543'],
#  'DVRC5': ['544', '544'],
#  'DVRC6': ['545', '545'],
#  'DVRC7': ['546', '546'],
#  'DVRC8': ['547', '547'],
#  'DVRC9': ['548', '548'],
#  'DTP1_AGE': ['549', '550'],
#  'DTP2_AGE': ['551', '552'],
#  'DTP3_AGE': ['553', '554'],
#  'DTP4_AGE': ['555', '556'],
#  'DTP5_AGE': ['557', '558'],
#  'DTP6_AGE': ['559', '560'],
#  'DTP7_AGE': ['561', '561'],
#  'DTP8_AGE': ['562', '562'],
#  'DTP9_AGE': ['563', '563'],
#  'FLU1_AGE': ['564', '565'],
#  'FLU2_AGE': ['566', '567'],
#  'FLU3_AGE': ['568', '569'],
#  'FLU4_AGE': ['570', '571'],
#  'FLU5_AGE': ['572', '573'],
#  'FLU6_AGE': ['574', '575'],
#  'FLU7_AGE': ['576', '576'],
#  'FLU8_AGE': ['577', '577'],
#  'FLU9_AGE': ['578', '578'],
#  'HEA1_AGE': ['579', '580'],
#  'HEA2_AGE': ['581', '582'],
#  'HEA3_AGE': ['583', '584'],
#  'HEA4_AGE': ['585', '586'],
#  'HEA5_AGE': ['587', '587'],
#  'HEA6_AGE': ['588', '588'],
#  'HEA7_AGE': ['589', '589'],
#  'HEA8_AGE': ['590', '590'],
#  'HEA9_AGE': ['591', '591'],
#  'HEP1_AGE': ['592', '593'],
#  'HEP2_AGE': ['594', '595'],
#  'HEP3_AGE': ['596', '597'],
#  'HEP4_AGE': ['598', '599'],
#  'HEP5_AGE': ['600', '601'],
#  'HEP6_AGE': ['602', '603'],
#  'HEP7_AGE': ['604', '605'],
#  'HEP8_AGE': ['606', '606'],
#  'HEP9_AGE': ['607', '607'],
#  'HIB1_AGE': ['608', '609'],
#  'HIB2_AGE': ['610', '611'],
#  'HIB3_AGE': ['612', '613'],
#  'HIB4_AGE': ['614', '615'],
#  'HIB5_AGE': ['616', '617'],
#  'HIB6_AGE': ['618', '619'],
#  'HIB7_AGE': ['620', '621'],
#  'HIB8_AGE': ['622', '622'],
#  'HIB9_AGE': ['623', '623'],
#  'MMR1_AGE': ['624', '625'],
#  'MMR2_AGE': ['626', '627'],
#  'MMR3_AGE': ['628', '629'],
#  'MMR4_AGE': ['630', '631'],
#  'MMR5_AGE': ['632', '632'],
#  'MMR6_AGE': ['633', '633'],
#  'MMR7_AGE': ['634', '634'],
#  'MMR8_AGE': ['635', '635'],
#  'MMR9_AGE': ['636', '636'],
#  'MP1_AGE': ['637', '637'],
#  'MP2_AGE': ['638', '638'],
#  'MP3_AGE': ['639', '639'],
#  'MP4_AGE': ['640', '640'],
#  'MP5_AGE': ['641', '641'],
#  'MP6_AGE': ['642', '642'],
#  'MP7_AGE': ['643', '643'],
#  'MP8_AGE': ['644', '644'],
#  'MP9_AGE': ['645', '645'],
#  'MPR1_AGE': ['646', '646'],
#  'MPR2_AGE': ['647', '647'],
#  'MPR3_AGE': ['648', '648'],
#  'MPR4_AGE': ['649', '649'],
#  'MPR5_AGE': ['650', '650'],
#  'MPR6_AGE': ['651', '651'],
#  'MPR7_AGE': ['652', '652'],
#  'MPR8_AGE': ['653', '653'],
#  'MPR9_AGE': ['654', '654'],
#  'PCV1_AGE': ['655', '656'],
#  'PCV2_AGE': ['657', '658'],
#  'PCV3_AGE': ['659', '660'],
#  'PCV4_AGE': ['661', '662'],
#  'PCV5_AGE': ['663', '664'],
#  'PCV6_AGE': ['665', '666'],
#  'PCV7_AGE': ['667', '668'],
#  'PCV8_AGE': ['669', '669'],
#  'PCV9_AGE': ['670', '670'],
#  'POL1_AGE': ['671', '672'],
#  'POL2_AGE': ['673', '674'],
#  'POL3_AGE': ['675', '676'],
#  'POL4_AGE': ['677', '678'],
#  'POL5_AGE': ['679', '680'],
#  'POL6_AGE': ['681', '682'],
#  'POL7_AGE': ['683', '683'],
#  'POL8_AGE': ['684', '684'],
#  'POL9_AGE': ['685', '685'],
#  'RB1_AGE': ['686', '687'],
#  'RB2_AGE': ['688', '688'],
#  'RB3_AGE': ['689', '689'],
#  'RB4_AGE': ['690', '690'],
#  'RB5_AGE': ['691', '691'],
#  'RB6_AGE': ['692', '692'],
#  'RB7_AGE': ['693', '693'],
#  'RB8_AGE': ['694', '694'],
#  'RB9_AGE': ['695', '695'],
#  'ROT1_AGE': ['696', '697'],
#  'ROT2_AGE': ['698', '699'],
#  'ROT3_AGE': ['700', '701'],
#  'ROT4_AGE': ['702', '703'],
#  'ROT5_AGE': ['704', '704'],
#  'ROT6_AGE': ['705', '705'],
#  'ROT7_AGE': ['706', '706'],
#  'ROT8_AGE': ['707', '707'],
#  'ROT9_AGE': ['708', '708'],
#  'VRC1_AGE': ['709', '710'],
#  'VRC2_AGE': ['711', '712'],
#  'VRC3_AGE': ['713', '714'],
#  'VRC4_AGE': ['715', '715'],
#  'VRC5_AGE': ['716', '716'],
#  'VRC6_AGE': ['717', '717'],
#  'VRC7_AGE': ['718', '718'],
#  'VRC8_AGE': ['719', '719'],
#  'VRC9_AGE': ['720', '720'],
#  'XDTPTY1': ['721', '722'],
#  'XDTPTY2': ['723', '724'],
#  'XDTPTY3': ['725', '726'],
#  'XDTPTY4': ['727', '728'],
#  'XDTPTY5': ['729', '730'],
#  'XDTPTY6': ['731', '732'],
#  'XDTPTY7': ['733', '733'],
#  'XDTPTY8': ['734', '734'],
#  'XDTPTY9': ['735', '735'],
#  'XFLUTY1': ['736', '737'],
#  'XFLUTY2': ['738', '739'],
#  'XFLUTY3': ['740', '741'],
#  'XFLUTY4': ['742', '743'],
#  'XFLUTY5': ['744', '745'],
#  'XFLUTY6': ['746', '747'],
#  'XFLUTY7': ['748', '748'],
#  'XFLUTY8': ['749', '749'],
#  'XFLUTY9': ['750', '750'],
#  'XHEPTY1': ['751', '752'],
#  'XHEPTY2': ['753', '754'],
#  'XHEPTY3': ['755', '756'],
#  'XHEPTY4': ['757', '758'],
#  'XHEPTY5': ['759', '760'],
#  'XHEPTY6': ['761', '762'],
#  'XHEPTY7': ['763', '764'],
#  'XHEPTY8': ['765', '765'],
#  'XHEPTY9': ['766', '766'],
#  'XHIBTY1': ['767', '768'],
#  'XHIBTY2': ['769', '770'],
#  'XHIBTY3': ['771', '772'],
#  'XHIBTY4': ['773', '774'],
#  'XHIBTY5': ['775', '776'],
#  'XHIBTY6': ['777', '778'],
#  'XHIBTY7': ['779', '780'],
#  'XHIBTY8': ['781', '781'],
#  'XHIBTY9': ['782', '782'],
#  'XMMRTY1': ['783', '784'],
#  'XMMRTY2': ['785', '786'],
#  'XMMRTY3': ['787', '788'],
#  'XMMRTY4': ['789', '790'],
#  'XMMRTY5': ['791', '791'],
#  'XMMRTY6': ['792', '792'],
#  'XMMRTY7': ['793', '793'],
#  'XMMRTY8': ['794', '794'],
#  'XMMRTY9': ['795', '795'],
#  'XPCVTY1': ['796', '797'],
#  'XPCVTY2': ['798', '799'],
#  'XPCVTY3': ['800', '801'],
#  'XPCVTY4': ['802', '803'],
#  'XPCVTY5': ['804', '805'],
#  'XPCVTY6': ['806', '807'],
#  'XPCVTY7': ['808', '809'],
#  'XPCVTY8': ['810', '810'],
#  'XPCVTY9': ['811', '811'],
#  'XPOLTY1': ['812', '813'],
#  'XPOLTY2': ['814', '815'],
#  'XPOLTY3': ['816', '817'],
#  'XPOLTY4': ['818', '819'],
#  'XPOLTY5': ['820', '821'],
#  'XPOLTY6': ['822', '823'],
#  'XPOLTY7': ['824', '824'],
#  'XPOLTY8': ['825', '825'],
#  'XPOLTY9': ['826', '826'],
#  'XROTTY1': ['827', '828'],
#  'XROTTY2': ['829', '830'],
#  'XROTTY3': ['831', '832'],
#  'XROTTY4': ['833', '834'],
#  'XROTTY5': ['835', '836'],
#  'XROTTY6': ['837', '837'],
#  'XROTTY7': ['838', '838'],
#  'XROTTY8': ['839', '839'],
#  'XROTTY9': ['840', '840'],
#  'XVRCTY1': ['841', '842'],
#  'XVRCTY2': ['843', '844'],
#  'XVRCTY3': ['845', '846'],
#  'XVRCTY4': ['847', '847'],
#  'XVRCTY5': ['848', '848'],
#  'XVRCTY6': ['849', '849'],
#  'XVRCTY7': ['850', '850'],
#  'XVRCTY8': ['851', '851'],
#  'XVRCTY9': ['852', '852'],
#  'INS_1': ['853', '854'],
#  'INS_2': ['855', '856'],
#  'INS_3': ['857', '858'],
#  'INS_3A': ['859', '860'],
#  'INS_4_5': ['861', '862'],
#  'INS_6': ['863', '864'],
#  'INS_11': ['865', '866']}

# %% [markdown]
# <b>Cool...</b> This is something similar to what we need for our for loop.

# %%
#Just rechecking the length (# of rows) again...
len(NIS_dict1)
# Out:
# 462

# %%
#Just rechecking that it is still a dictionary type...
type(NIS_dict1)
# Out:
# dict

# %%
#Let's pretty print the dictionary for now reason...just to try it.
from pprint import pprint

# %%
def printplus(obj):
    """
    Pretty-prints the object passed in.

    """
    # Dict
    if isinstance(obj, dict):
        for k, v in sorted(obj.items()):
            print (u'{0}: {1}'.format(k, v))

    # List or tuple            
    elif isinstance(obj, list) or isinstance(obj, tuple):
        for x in obj:
            print (x)

    # Other
    else:
        print (obj)

# %%
#Now we pretty print the dictionary.
printplus(NIS_dict1)
# Out:
# AGECPOXR: ['97', '97']
# AGEGRP: ['101', '101']
# BFENDFL06: ['126', '126']
# BFFORMFL06: ['127', '127']
# BF_ENDR06: ['102', '109']
# BF_EXCLR06: ['110', '117']
# BF_FORMR08: ['118', '125']
# C1R: ['128', '128']
# C5R: ['129', '130']
# CBF_01: ['131', '132']
# CEN_REG: ['133', '133']
# CHILDNM: ['134', '134']
# CWIC_01: ['135', '136']
# CWIC_02: ['137', '138']
# D6R: ['184', '184']
# D7: ['185', '185']
# DDTP1: ['277', '280']
# DDTP2: ['281', '284']
# DDTP3: ['285', '288']
# DDTP4: ['289', '292']
# DDTP5: ['293', '296']
# DDTP6: ['297', '300']
# DDTP7: ['301', '301']
# DDTP8: ['302', '302']
# DDTP9: ['303', '303']
# DFLU1: ['304', '307']
# DFLU2: ['308', '311']
# DFLU3: ['312', '315']
# DFLU4: ['316', '319']
# DFLU5: ['320', '323']
# DFLU6: ['324', '327']
# DFLU7: ['328', '328']
# DFLU8: ['329', '329']
# DFLU9: ['330', '330']
# DHEPA1: ['331', '334']
# DHEPA2: ['335', '338']
# DHEPA3: ['339', '342']
# DHEPA4: ['343', '346']
# DHEPA5: ['347', '347']
# DHEPA6: ['348', '348']
# DHEPA7: ['349', '349']
# DHEPA8: ['350', '350']
# DHEPA9: ['351', '351']
# DHEPB1: ['352', '355']
# DHEPB2: ['356', '359']
# DHEPB3: ['360', '363']
# DHEPB4: ['364', '367']
# DHEPB5: ['368', '371']
# DHEPB6: ['372', '374']
# DHEPB7: ['375', '377']
# DHEPB8: ['378', '378']
# DHEPB9: ['379', '379']
# DHIB1: ['380', '383']
# DHIB2: ['384', '387']
# DHIB3: ['388', '391']
# DHIB4: ['392', '395']
# DHIB5: ['396', '399']
# DHIB6: ['400', '402']
# DHIB7: ['403', '405']
# DHIB8: ['406', '406']
# DHIB9: ['407', '407']
# DMMR1: ['408', '411']
# DMMR2: ['412', '415']
# DMMR3: ['416', '418']
# DMMR4: ['419', '421']
# DMMR5: ['422', '422']
# DMMR6: ['423', '423']
# DMMR7: ['424', '424']
# DMMR8: ['425', '425']
# DMMR9: ['426', '426']
# DMP1: ['427', '427']
# DMP2: ['428', '428']
# DMP3: ['429', '429']
# DMP4: ['430', '430']
# DMP5: ['431', '431']
# DMP6: ['432', '432']
# DMP7: ['433', '433']
# DMP8: ['434', '434']
# DMP9: ['435', '435']
# DMPRB1: ['436', '438']
# DMPRB2: ['439', '439']
# DMPRB3: ['440', '440']
# DMPRB4: ['441', '441']
# DMPRB5: ['442', '442']
# DMPRB6: ['443', '443']
# DMPRB7: ['444', '444']
# DMPRB8: ['445', '445']
# DMPRB9: ['446', '446']
# DPCV1: ['447', '450']
# DPCV2: ['451', '454']
# DPCV3: ['455', '458']
# DPCV4: ['459', '462']
# DPCV5: ['463', '466']
# DPCV6: ['467', '469']
# DPCV7: ['470', '472']
# DPCV8: ['473', '473']
# DPCV9: ['474', '474']
# DPOLIO1: ['475', '478']
# DPOLIO2: ['479', '482']
# DPOLIO3: ['483', '486']
# DPOLIO4: ['487', '490']
# DPOLIO5: ['491', '493']
# DPOLIO6: ['494', '496']
# DPOLIO7: ['497', '497']
# DPOLIO8: ['498', '498']
# DPOLIO9: ['499', '499']
# DRB1: ['500', '502']
# DRB2: ['503', '503']
# DRB3: ['504', '504']
# DRB4: ['505', '505']
# DRB5: ['506', '506']
# DRB6: ['507', '507']
# DRB7: ['508', '508']
# DRB8: ['509', '509']
# DRB9: ['510', '510']
# DROT1: ['511', '513']
# DROT2: ['514', '516']
# DROT3: ['517', '520']
# DROT4: ['521', '523']
# DROT5: ['524', '526']
# DROT6: ['527', '527']
# DROT7: ['528', '528']
# DROT8: ['529', '529']
# DROT9: ['530', '530']
# DTP1_AGE: ['549', '550']
# DTP2_AGE: ['551', '552']
# DTP3_AGE: ['553', '554']
# DTP4_AGE: ['555', '556']
# DTP5_AGE: ['557', '558']
# DTP6_AGE: ['559', '560']
# DTP7_AGE: ['561', '561']
# DTP8_AGE: ['562', '562']
# DTP9_AGE: ['563', '563']
# DVRC1: ['531', '534']
# DVRC2: ['535', '538']
# DVRC3: ['539', '542']
# DVRC4: ['543', '543']
# DVRC5: ['544', '544']
# DVRC6: ['545', '545']
# DVRC7: ['546', '546']
# DVRC8: ['547', '547']
# DVRC9: ['548', '548']
# EDUC1: ['139', '139']
# ESTIAP14: ['177', '179']
# EST_GRANT: ['180', '181']
# FLU1_AGE: ['564', '565']
# FLU2_AGE: ['566', '567']
# FLU3_AGE: ['568', '569']
# FLU4_AGE: ['570', '571']
# FLU5_AGE: ['572', '573']
# FLU6_AGE: ['574', '575']
# FLU7_AGE: ['576', '576']
# FLU8_AGE: ['577', '577']
# FLU9_AGE: ['578', '578']
# FRSTBRN: ['140', '140']
# HAD_CPOX: ['98', '99']
# HEA1_AGE: ['579', '580']
# HEA2_AGE: ['581', '582']
# HEA3_AGE: ['583', '584']
# HEA4_AGE: ['585', '586']
# HEA5_AGE: ['587', '587']
# HEA6_AGE: ['588', '588']
# HEA7_AGE: ['589', '589']
# HEA8_AGE: ['590', '590']
# HEA9_AGE: ['591', '591']
# HEP1_AGE: ['592', '593']
# HEP2_AGE: ['594', '595']
# HEP3_AGE: ['596', '597']
# HEP4_AGE: ['598', '599']
# HEP5_AGE: ['600', '601']
# HEP6_AGE: ['602', '603']
# HEP7_AGE: ['604', '605']
# HEP8_AGE: ['606', '606']
# HEP9_AGE: ['607', '607']
# HEP_BRTH: ['190', '190']
# HEP_FLAG: ['191', '191']
# HIB1_AGE: ['608', '609']
# HIB2_AGE: ['610', '611']
# HIB3_AGE: ['612', '613']
# HIB4_AGE: ['614', '615']
# HIB5_AGE: ['616', '617']
# HIB6_AGE: ['618', '619']
# HIB7_AGE: ['620', '621']
# HIB8_AGE: ['622', '622']
# HIB9_AGE: ['623', '623']
# INCPORAR: ['142', '157']
# INCPOV1: ['158', '158']
# INCQ298A: ['159', '160']
# INS_1: ['853', '854']
# INS_11: ['865', '866']
# INS_2: ['855', '856']
# INS_3: ['857', '858']
# INS_3A: ['859', '860']
# INS_4_5: ['861', '862']
# INS_6: ['863', '864']
# INTRP: ['161', '161']
# I_HISP_K: ['141', '141']
# LANGUAGE: ['162', '162']
# MARITAL2: ['164', '164']
# MMR1_AGE: ['624', '625']
# MMR2_AGE: ['626', '627']
# MMR3_AGE: ['628', '629']
# MMR4_AGE: ['630', '631']
# MMR5_AGE: ['632', '632']
# MMR6_AGE: ['633', '633']
# MMR7_AGE: ['634', '634']
# MMR8_AGE: ['635', '635']
# MMR9_AGE: ['636', '636']
# MOBIL_I: ['165', '165']
# MP1_AGE: ['637', '637']
# MP2_AGE: ['638', '638']
# MP3_AGE: ['639', '639']
# MP4_AGE: ['640', '640']
# MP5_AGE: ['641', '641']
# MP6_AGE: ['642', '642']
# MP7_AGE: ['643', '643']
# MP8_AGE: ['644', '644']
# MP9_AGE: ['645', '645']
# MPR1_AGE: ['646', '646']
# MPR2_AGE: ['647', '647']
# MPR3_AGE: ['648', '648']
# MPR4_AGE: ['649', '649']
# MPR5_AGE: ['650', '650']
# MPR6_AGE: ['651', '651']
# MPR7_AGE: ['652', '652']
# MPR8_AGE: ['653', '653']
# MPR9_AGE: ['654', '654']
# M_AGEGRP: ['163', '163']
# NUM_CELLS_HH: ['168', '169']
# NUM_CELLS_PARENTS: ['170', '171']
# NUM_PHONE: ['166', '167']
# N_PRVR: ['186', '186']
# PCV1_AGE: ['655', '656']
# PCV2_AGE: ['657', '658']
# PCV3_AGE: ['659', '660']
# PCV4_AGE: ['661', '662']
# PCV5_AGE: ['663', '664']
# PCV6_AGE: ['665', '666']
# PCV7_AGE: ['667', '668']
# PCV8_AGE: ['669', '669']
# PCV9_AGE: ['670', '670']
# PDAT: ['12', '12']
# POL1_AGE: ['671', '672']
# POL2_AGE: ['673', '674']
# POL3_AGE: ['675', '676']
# POL4_AGE: ['677', '678']
# POL5_AGE: ['679', '680']
# POL6_AGE: ['681', '682']
# POL7_AGE: ['683', '683']
# POL8_AGE: ['684', '684']
# POL9_AGE: ['685', '685']
# PROVWT_D: ['13', '31']
# PROVWT_D_TERR: ['32', '50']
# PROV_FAC: ['187', '187']
# PU431331: ['262', '262']
# PU4313313: ['265', '265']
# PU4313314: ['267', '267']
# PU431_31: ['264', '264']
# PU431_314: ['269', '269']
# PUT43133: ['270', '270']
# PUTD4313: ['272', '272']
# P_NUHEPX: ['192', '192']
# P_NUHIBX: ['193', '193']
# P_NUHPHB: ['194', '194']
# P_NUMDAH: ['195', '195']
# P_NUMDHI: ['196', '196']
# P_NUMDIH: ['197', '197']
# P_NUMDTA: ['198', '198']
# P_NUMDTP: ['199', '199']
# P_NUMFLU: ['200', '200']
# P_NUMFLUL: ['201', '201']
# P_NUMFLUM: ['202', '202']
# P_NUMFLUN: ['203', '203']
# P_NUMHEA: ['204', '204']
# P_NUMHEN: ['205', '205']
# P_NUMHEP: ['206', '206']
# P_NUMHG: ['207', '207']
# P_NUMHHY: ['208', '208']
# P_NUMHIB: ['209', '209']
# P_NUMHIN: ['210', '210']
# P_NUMHION: ['211', '211']
# P_NUMHM: ['212', '212']
# P_NUMHS: ['213', '213']
# P_NUMIPV: ['214', '214']
# P_NUMMCN: ['215', '215']
# P_NUMMMR: ['216', '216']
# P_NUMMMRX: ['217', '217']
# P_NUMMMX: ['218', '218']
# P_NUMMP: ['219', '219']
# P_NUMMPR: ['220', '220']
# P_NUMMRV: ['221', '221']
# P_NUMMS: ['222', '222']
# P_NUMMSM: ['223', '223']
# P_NUMMSR: ['224', '224']
# P_NUMOLN: ['225', '225']
# P_NUMOPV: ['226', '226']
# P_NUMPCC: ['229', '229']
# P_NUMPCC13: ['231', '231']
# P_NUMPCC7: ['230', '230']
# P_NUMPCCN: ['232', '232']
# P_NUMPCN: ['233', '233']
# P_NUMPCP: ['228', '228']
# P_NUMPCV: ['227', '227']
# P_NUMPOL: ['234', '234']
# P_NUMRB: ['235', '235']
# P_NUMRG: ['236', '236']
# P_NUMRM: ['237', '237']
# P_NUMRO: ['238', '238']
# P_NUMROT: ['239', '239']
# P_NUMTPN: ['240', '240']
# P_NUMVRC: ['241', '241']
# P_NUMVRN: ['242', '242']
# P_NUMVRX: ['243', '243']
# P_U12VRC: ['244', '244']
# P_UTD331: ['245', '245']
# P_UTD431: ['246', '246']
# P_UTD431H313_ROUT_S: ['266', '266']
# P_UTD431H314_ROUT_S: ['268', '268']
# P_UTD431H31_ROUT_S: ['263', '263']
# P_UTD431H3_ROUT_S: ['271', '271']
# P_UTD431H_ROUT_S: ['273', '273']
# P_UTDHEP: ['247', '247']
# P_UTDHEPA1: ['248', '248']
# P_UTDHEPA2: ['249', '249']
# P_UTDHIB: ['250', '250']
# P_UTDHIB_ROUT_S: ['251', '251']
# P_UTDHIB_SHORT_S: ['252', '252']
# P_UTDMCV: ['253', '253']
# P_UTDMMX: ['254', '254']
# P_UTDPC3: ['255', '255']
# P_UTDPCV: ['256', '256']
# P_UTDPCVB13: ['257', '257']
# P_UTDPOL: ['258', '258']
# P_UTDROT_S: ['259', '259']
# P_UTDTP3: ['260', '260']
# P_UTDTP4: ['261', '261']
# RACEETHK: ['173', '173']
# RACE_K: ['172', '172']
# RB1_AGE: ['686', '687']
# RB2_AGE: ['688', '688']
# RB3_AGE: ['689', '689']
# RB4_AGE: ['690', '690']
# RB5_AGE: ['691', '691']
# RB6_AGE: ['692', '692']
# RB7_AGE: ['693', '693']
# RB8_AGE: ['694', '694']
# RB9_AGE: ['695', '695']
# RDDWT_D: ['51', '69']
# RDDWT_D_TERR: ['70', '88']
# REGISTRY: ['188', '188']
# RENT_OWN: ['174', '175']
# ROT1_AGE: ['696', '697']
# ROT2_AGE: ['698', '699']
# ROT3_AGE: ['700', '701']
# ROT4_AGE: ['702', '703']
# ROT5_AGE: ['704', '704']
# ROT6_AGE: ['705', '705']
# ROT7_AGE: ['706', '706']
# ROT8_AGE: ['707', '707']
# ROT9_AGE: ['708', '708']
# SEQNUMC: ['1', '6']
# SEQNUMHH: ['7', '11']
# SEX: ['176', '176']
# SHOTCARD: ['100', '100']
# STATE: ['182', '183']
# STRATUM: ['89', '92']
# U1D_HEP: ['274', '274']
# U2D_HEP: ['275', '275']
# U3D_HEP: ['276', '276']
# VFC_ORDER: ['189', '189']
# VRC1_AGE: ['709', '710']
# VRC2_AGE: ['711', '712']
# VRC3_AGE: ['713', '714']
# VRC4_AGE: ['715', '715']
# VRC5_AGE: ['716', '716']
# VRC6_AGE: ['717', '717']
# VRC7_AGE: ['718', '718']
# VRC8_AGE: ['719', '719']
# VRC9_AGE: ['720', '720']
# Variable Name: ['Position', 'Position']
# XDTPTY1: ['721', '722']
# XDTPTY2: ['723', '724']
# XDTPTY3: ['725', '726']
# XDTPTY4: ['727', '728']
# XDTPTY5: ['729', '730']
# XDTPTY6: ['731', '732']
# XDTPTY7: ['733', '733']
# XDTPTY8: ['734', '734']
# XDTPTY9: ['735', '735']
# XFLUTY1: ['736', '737']
# XFLUTY2: ['738', '739']
# XFLUTY3: ['740', '741']
# XFLUTY4: ['742', '743']
# XFLUTY5: ['744', '745']
# XFLUTY6: ['746', '747']
# XFLUTY7: ['748', '748']
# XFLUTY8: ['749', '749']
# XFLUTY9: ['750', '750']
# XHEPTY1: ['751', '752']
# XHEPTY2: ['753', '754']
# XHEPTY3: ['755', '756']
# XHEPTY4: ['757', '758']
# XHEPTY5: ['759', '760']
# XHEPTY6: ['761', '762']
# XHEPTY7: ['763', '764']
# XHEPTY8: ['765', '765']
# XHEPTY9: ['766', '766']
# XHIBTY1: ['767', '768']
# XHIBTY2: ['769', '770']
# XHIBTY3: ['771', '772']
# XHIBTY4: ['773', '774']
# XHIBTY5: ['775', '776']
# XHIBTY6: ['777', '778']
# XHIBTY7: ['779', '780']
# XHIBTY8: ['781', '781']
# XHIBTY9: ['782', '782']
# XMMRTY1: ['783', '784']
# XMMRTY2: ['785', '786']
# XMMRTY3: ['787', '788']
# XMMRTY4: ['789', '790']
# XMMRTY5: ['791', '791']
# XMMRTY6: ['792', '792']
# XMMRTY7: ['793', '793']
# XMMRTY8: ['794', '794']
# XMMRTY9: ['795', '795']
# XPCVTY1: ['796', '797']
# XPCVTY2: ['798', '799']
# XPCVTY3: ['800', '801']
# XPCVTY4: ['802', '803']
# XPCVTY5: ['804', '805']
# XPCVTY6: ['806', '807']
# XPCVTY7: ['808', '809']
# XPCVTY8: ['810', '810']
# XPCVTY9: ['811', '811']
# XPOLTY1: ['812', '813']
# XPOLTY2: ['814', '815']
# XPOLTY3: ['816', '817']
# XPOLTY4: ['818', '819']
# XPOLTY5: ['820', '821']
# XPOLTY6: ['822', '823']
# XPOLTY7: ['824', '824']
# XPOLTY8: ['825', '825']
# XPOLTY9: ['826', '826']
# XROTTY1: ['827', '828']
# XROTTY2: ['829', '830']
# XROTTY3: ['831', '832']
# XROTTY4: ['833', '834']
# XROTTY5: ['835', '836']
# XROTTY6: ['837', '837']
# XROTTY7: ['838', '838']
# XROTTY8: ['839', '839']
# XROTTY9: ['840', '840']
# XVRCTY1: ['841', '842']
# XVRCTY2: ['843', '844']
# XVRCTY3: ['845', '846']
# XVRCTY4: ['847', '847']
# XVRCTY5: ['848', '848']
# XVRCTY6: ['849', '849']
# XVRCTY7: ['850', '850']
# XVRCTY8: ['851', '851']
# XVRCTY9: ['852', '852']
# YEAR: ['93', '96']

# %% [markdown]
# Nice! The pretty print really shows us how the .dat file can be used as a dictionary.

# %%
#Here is a TESt to print the values of the first Variable Name...
print(NIS_dict1['SEQNUMC'])
# Out:
# ['1', '6']

# %%
#EXAMPLE of what to use in the final for loop:

for key, value in NIS_dict1.items():
    print(key, '=', value)
# Out:
# SEQNUMC = ['1', '6']
# SEQNUMHH = ['7', '11']
# PDAT = ['12', '12']
# PROVWT_D = ['13', '31']
# PROVWT_D_TERR = ['32', '50']
# RDDWT_D = ['51', '69']
# RDDWT_D_TERR = ['70', '88']
# STRATUM = ['89', '92']
# YEAR = ['93', '96']
# AGECPOXR = ['97', '97']
# HAD_CPOX = ['98', '99']
# SHOTCARD = ['100', '100']
# AGEGRP = ['101', '101']
# BF_ENDR06 = ['102', '109']
# BF_EXCLR06 = ['110', '117']
# BF_FORMR08 = ['118', '125']
# BFENDFL06 = ['126', '126']
# BFFORMFL06 = ['127', '127']
# C1R = ['128', '128']
# C5R = ['129', '130']
# CBF_01 = ['131', '132']
# CEN_REG = ['133', '133']
# CHILDNM = ['134', '134']
# CWIC_01 = ['135', '136']
# CWIC_02 = ['137', '138']
# EDUC1 = ['139', '139']
# FRSTBRN = ['140', '140']
# I_HISP_K = ['141', '141']
# INCPORAR = ['142', '157']
# INCPOV1 = ['158', '158']
# INCQ298A = ['159', '160']
# INTRP = ['161', '161']
# LANGUAGE = ['162', '162']
# M_AGEGRP = ['163', '163']
# Variable Name = ['Position', 'Position']
# MARITAL2 = ['164', '164']
# MOBIL_I = ['165', '165']
# NUM_PHONE = ['166', '167']
# NUM_CELLS_HH = ['168', '169']
# NUM_CELLS_PARENTS = ['170', '171']
# RACE_K = ['172', '172']
# RACEETHK = ['173', '173']
# RENT_OWN = ['174', '175']
# SEX = ['176', '176']
# ESTIAP14 = ['177', '179']
# EST_GRANT = ['180', '181']
# STATE = ['182', '183']
# D6R = ['184', '184']
# D7 = ['185', '185']
# N_PRVR = ['186', '186']
# PROV_FAC = ['187', '187']
# REGISTRY = ['188', '188']
# VFC_ORDER = ['189', '189']
# HEP_BRTH = ['190', '190']
# HEP_FLAG = ['191', '191']
# P_NUHEPX = ['192', '192']
# P_NUHIBX = ['193', '193']
# P_NUHPHB = ['194', '194']
# P_NUMDAH = ['195', '195']
# P_NUMDHI = ['196', '196']
# P_NUMDIH = ['197', '197']
# P_NUMDTA = ['198', '198']
# P_NUMDTP = ['199', '199']
# P_NUMFLU = ['200', '200']
# P_NUMFLUL = ['201', '201']
# P_NUMFLUM = ['202', '202']
# P_NUMFLUN = ['203', '203']
# P_NUMHEA = ['204', '204']
# P_NUMHEN = ['205', '205']
# P_NUMHEP = ['206', '206']
# P_NUMHG = ['207', '207']
# P_NUMHHY = ['208', '208']
# P_NUMHIB = ['209', '209']
# P_NUMHIN = ['210', '210']
# P_NUMHION = ['211', '211']
# P_NUMHM = ['212', '212']
# P_NUMHS = ['213', '213']
# P_NUMIPV = ['214', '214']
# P_NUMMCN = ['215', '215']
# P_NUMMMR = ['216', '216']
# P_NUMMMRX = ['217', '217']
# P_NUMMMX = ['218', '218']
# P_NUMMP = ['219', '219']
# P_NUMMPR = ['220', '220']
# P_NUMMRV = ['221', '221']
# P_NUMMS = ['222', '222']
# P_NUMMSM = ['223', '223']
# P_NUMMSR = ['224', '224']
# P_NUMOLN = ['225', '225']
# P_NUMOPV = ['226', '226']
# P_NUMPCV = ['227', '227']
# P_NUMPCP = ['228', '228']
# P_NUMPCC = ['229', '229']
# P_NUMPCC7 = ['230', '230']
# P_NUMPCC13 = ['231', '231']
# P_NUMPCCN = ['232', '232']
# P_NUMPCN = ['233', '233']
# P_NUMPOL = ['234', '234']
# P_NUMRB = ['235', '235']
# P_NUMRG = ['236', '236']
# P_NUMRM = ['237', '237']
# P_NUMRO = ['238', '238']
# P_NUMROT = ['239', '239']
# P_NUMTPN = ['240', '240']
# P_NUMVRC = ['241', '241']
# P_NUMVRN = ['242', '242']
# P_NUMVRX = ['243', '243']
# P_U12VRC = ['244', '244']
# P_UTD331 = ['245', '245']
# P_UTD431 = ['246', '246']
# P_UTDHEP = ['247', '247']
# P_UTDHEPA1 = ['248', '248']
# P_UTDHEPA2 = ['249', '249']
# P_UTDHIB = ['250', '250']
# P_UTDHIB_ROUT_S = ['251', '251']
# P_UTDHIB_SHORT_S = ['252', '252']
# P_UTDMCV = ['253', '253']
# P_UTDMMX = ['254', '254']
# P_UTDPC3 = ['255', '255']
# P_UTDPCV = ['256', '256']
# P_UTDPCVB13 = ['257', '257']
# P_UTDPOL = ['258', '258']
# P_UTDROT_S = ['259', '259']
# P_UTDTP3 = ['260', '260']
# P_UTDTP4 = ['261', '261']
# PU431331 = ['262', '262']
# P_UTD431H31_ROUT_S = ['263', '263']
# PU431_31 = ['264', '264']
# PU4313313 = ['265', '265']
# P_UTD431H313_ROUT_S = ['266', '266']
# PU4313314 = ['267', '267']
# P_UTD431H314_ROUT_S = ['268', '268']
# PU431_314 = ['269', '269']
# PUT43133 = ['270', '270']
# P_UTD431H3_ROUT_S = ['271', '271']
# PUTD4313 = ['272', '272']
# P_UTD431H_ROUT_S = ['273', '273']
# U1D_HEP = ['274', '274']
# U2D_HEP = ['275', '275']
# U3D_HEP = ['276', '276']
# DDTP1 = ['277', '280']
# DDTP2 = ['281', '284']
# DDTP3 = ['285', '288']
# DDTP4 = ['289', '292']
# DDTP5 = ['293', '296']
# DDTP6 = ['297', '300']
# DDTP7 = ['301', '301']
# DDTP8 = ['302', '302']
# DDTP9 = ['303', '303']
# DFLU1 = ['304', '307']
# DFLU2 = ['308', '311']
# DFLU3 = ['312', '315']
# DFLU4 = ['316', '319']
# DFLU5 = ['320', '323']
# DFLU6 = ['324', '327']
# DFLU7 = ['328', '328']
# DFLU8 = ['329', '329']
# DFLU9 = ['330', '330']
# DHEPA1 = ['331', '334']
# DHEPA2 = ['335', '338']
# DHEPA3 = ['339', '342']
# DHEPA4 = ['343', '346']
# DHEPA5 = ['347', '347']
# DHEPA6 = ['348', '348']
# DHEPA7 = ['349', '349']
# DHEPA8 = ['350', '350']
# DHEPA9 = ['351', '351']
# DHEPB1 = ['352', '355']
# DHEPB2 = ['356', '359']
# DHEPB3 = ['360', '363']
# DHEPB4 = ['364', '367']
# DHEPB5 = ['368', '371']
# DHEPB6 = ['372', '374']
# DHEPB7 = ['375', '377']
# DHEPB8 = ['378', '378']
# DHEPB9 = ['379', '379']
# DHIB1 = ['380', '383']
# DHIB2 = ['384', '387']
# DHIB3 = ['388', '391']
# DHIB4 = ['392', '395']
# DHIB5 = ['396', '399']
# DHIB6 = ['400', '402']
# DHIB7 = ['403', '405']
# DHIB8 = ['406', '406']
# DHIB9 = ['407', '407']
# DMMR1 = ['408', '411']
# DMMR2 = ['412', '415']
# DMMR3 = ['416', '418']
# DMMR4 = ['419', '421']
# DMMR5 = ['422', '422']
# DMMR6 = ['423', '423']
# DMMR7 = ['424', '424']
# DMMR8 = ['425', '425']
# DMMR9 = ['426', '426']
# DMP1 = ['427', '427']
# DMP2 = ['428', '428']
# DMP3 = ['429', '429']
# DMP4 = ['430', '430']
# DMP5 = ['431', '431']
# DMP6 = ['432', '432']
# DMP7 = ['433', '433']
# DMP8 = ['434', '434']
# DMP9 = ['435', '435']
# DMPRB1 = ['436', '438']
# DMPRB2 = ['439', '439']
# DMPRB3 = ['440', '440']
# DMPRB4 = ['441', '441']
# DMPRB5 = ['442', '442']
# DMPRB6 = ['443', '443']
# DMPRB7 = ['444', '444']
# DMPRB8 = ['445', '445']
# DMPRB9 = ['446', '446']
# DPCV1 = ['447', '450']
# DPCV2 = ['451', '454']
# DPCV3 = ['455', '458']
# DPCV4 = ['459', '462']
# DPCV5 = ['463', '466']
# DPCV6 = ['467', '469']
# DPCV7 = ['470', '472']
# DPCV8 = ['473', '473']
# DPCV9 = ['474', '474']
# DPOLIO1 = ['475', '478']
# DPOLIO2 = ['479', '482']
# DPOLIO3 = ['483', '486']
# DPOLIO4 = ['487', '490']
# DPOLIO5 = ['491', '493']
# DPOLIO6 = ['494', '496']
# DPOLIO7 = ['497', '497']
# DPOLIO8 = ['498', '498']
# DPOLIO9 = ['499', '499']
# DRB1 = ['500', '502']
# DRB2 = ['503', '503']
# DRB3 = ['504', '504']
# DRB4 = ['505', '505']
# DRB5 = ['506', '506']
# DRB6 = ['507', '507']
# DRB7 = ['508', '508']
# DRB8 = ['509', '509']
# DRB9 = ['510', '510']
# DROT1 = ['511', '513']
# DROT2 = ['514', '516']
# DROT3 = ['517', '520']
# DROT4 = ['521', '523']
# DROT5 = ['524', '526']
# DROT6 = ['527', '527']
# DROT7 = ['528', '528']
# DROT8 = ['529', '529']
# DROT9 = ['530', '530']
# DVRC1 = ['531', '534']
# DVRC2 = ['535', '538']
# DVRC3 = ['539', '542']
# DVRC4 = ['543', '543']
# DVRC5 = ['544', '544']
# DVRC6 = ['545', '545']
# DVRC7 = ['546', '546']
# DVRC8 = ['547', '547']
# DVRC9 = ['548', '548']
# DTP1_AGE = ['549', '550']
# DTP2_AGE = ['551', '552']
# DTP3_AGE = ['553', '554']
# DTP4_AGE = ['555', '556']
# DTP5_AGE = ['557', '558']
# DTP6_AGE = ['559', '560']
# DTP7_AGE = ['561', '561']
# DTP8_AGE = ['562', '562']
# DTP9_AGE = ['563', '563']
# FLU1_AGE = ['564', '565']
# FLU2_AGE = ['566', '567']
# FLU3_AGE = ['568', '569']
# FLU4_AGE = ['570', '571']
# FLU5_AGE = ['572', '573']
# FLU6_AGE = ['574', '575']
# FLU7_AGE = ['576', '576']
# FLU8_AGE = ['577', '577']
# FLU9_AGE = ['578', '578']
# HEA1_AGE = ['579', '580']
# HEA2_AGE = ['581', '582']
# HEA3_AGE = ['583', '584']
# HEA4_AGE = ['585', '586']
# HEA5_AGE = ['587', '587']
# HEA6_AGE = ['588', '588']
# HEA7_AGE = ['589', '589']
# HEA8_AGE = ['590', '590']
# HEA9_AGE = ['591', '591']
# HEP1_AGE = ['592', '593']
# HEP2_AGE = ['594', '595']
# HEP3_AGE = ['596', '597']
# HEP4_AGE = ['598', '599']
# HEP5_AGE = ['600', '601']
# HEP6_AGE = ['602', '603']
# HEP7_AGE = ['604', '605']
# HEP8_AGE = ['606', '606']
# HEP9_AGE = ['607', '607']
# HIB1_AGE = ['608', '609']
# HIB2_AGE = ['610', '611']
# HIB3_AGE = ['612', '613']
# HIB4_AGE = ['614', '615']
# HIB5_AGE = ['616', '617']
# HIB6_AGE = ['618', '619']
# HIB7_AGE = ['620', '621']
# HIB8_AGE = ['622', '622']
# HIB9_AGE = ['623', '623']
# MMR1_AGE = ['624', '625']
# MMR2_AGE = ['626', '627']
# MMR3_AGE = ['628', '629']
# MMR4_AGE = ['630', '631']
# MMR5_AGE = ['632', '632']
# MMR6_AGE = ['633', '633']
# MMR7_AGE = ['634', '634']
# MMR8_AGE = ['635', '635']
# MMR9_AGE = ['636', '636']
# MP1_AGE = ['637', '637']
# MP2_AGE = ['638', '638']
# MP3_AGE = ['639', '639']
# MP4_AGE = ['640', '640']
# MP5_AGE = ['641', '641']
# MP6_AGE = ['642', '642']
# MP7_AGE = ['643', '643']
# MP8_AGE = ['644', '644']
# MP9_AGE = ['645', '645']
# MPR1_AGE = ['646', '646']
# MPR2_AGE = ['647', '647']
# MPR3_AGE = ['648', '648']
# MPR4_AGE = ['649', '649']
# MPR5_AGE = ['650', '650']
# MPR6_AGE = ['651', '651']
# MPR7_AGE = ['652', '652']
# MPR8_AGE = ['653', '653']
# MPR9_AGE = ['654', '654']
# PCV1_AGE = ['655', '656']
# PCV2_AGE = ['657', '658']
# PCV3_AGE = ['659', '660']
# PCV4_AGE = ['661', '662']
# PCV5_AGE = ['663', '664']
# PCV6_AGE = ['665', '666']
# PCV7_AGE = ['667', '668']
# PCV8_AGE = ['669', '669']
# PCV9_AGE = ['670', '670']
# POL1_AGE = ['671', '672']
# POL2_AGE = ['673', '674']
# POL3_AGE = ['675', '676']
# POL4_AGE = ['677', '678']
# POL5_AGE = ['679', '680']
# POL6_AGE = ['681', '682']
# POL7_AGE = ['683', '683']
# POL8_AGE = ['684', '684']
# POL9_AGE = ['685', '685']
# RB1_AGE = ['686', '687']
# RB2_AGE = ['688', '688']
# RB3_AGE = ['689', '689']
# RB4_AGE = ['690', '690']
# RB5_AGE = ['691', '691']
# RB6_AGE = ['692', '692']
# RB7_AGE = ['693', '693']
# RB8_AGE = ['694', '694']
# RB9_AGE = ['695', '695']
# ROT1_AGE = ['696', '697']
# ROT2_AGE = ['698', '699']
# ROT3_AGE = ['700', '701']
# ROT4_AGE = ['702', '703']
# ROT5_AGE = ['704', '704']
# ROT6_AGE = ['705', '705']
# ROT7_AGE = ['706', '706']
# ROT8_AGE = ['707', '707']
# ROT9_AGE = ['708', '708']
# VRC1_AGE = ['709', '710']
# VRC2_AGE = ['711', '712']
# VRC3_AGE = ['713', '714']
# VRC4_AGE = ['715', '715']
# VRC5_AGE = ['716', '716']
# VRC6_AGE = ['717', '717']
# VRC7_AGE = ['718', '718']
# VRC8_AGE = ['719', '719']
# VRC9_AGE = ['720', '720']
# XDTPTY1 = ['721', '722']
# XDTPTY2 = ['723', '724']
# XDTPTY3 = ['725', '726']
# XDTPTY4 = ['727', '728']
# XDTPTY5 = ['729', '730']
# XDTPTY6 = ['731', '732']
# XDTPTY7 = ['733', '733']
# XDTPTY8 = ['734', '734']
# XDTPTY9 = ['735', '735']
# XFLUTY1 = ['736', '737']
# XFLUTY2 = ['738', '739']
# XFLUTY3 = ['740', '741']
# XFLUTY4 = ['742', '743']
# XFLUTY5 = ['744', '745']
# XFLUTY6 = ['746', '747']
# XFLUTY7 = ['748', '748']
# XFLUTY8 = ['749', '749']
# XFLUTY9 = ['750', '750']
# XHEPTY1 = ['751', '752']
# XHEPTY2 = ['753', '754']
# XHEPTY3 = ['755', '756']
# XHEPTY4 = ['757', '758']
# XHEPTY5 = ['759', '760']
# XHEPTY6 = ['761', '762']
# XHEPTY7 = ['763', '764']
# XHEPTY8 = ['765', '765']
# XHEPTY9 = ['766', '766']
# XHIBTY1 = ['767', '768']
# XHIBTY2 = ['769', '770']
# XHIBTY3 = ['771', '772']
# XHIBTY4 = ['773', '774']
# XHIBTY5 = ['775', '776']
# XHIBTY6 = ['777', '778']
# XHIBTY7 = ['779', '780']
# XHIBTY8 = ['781', '781']
# XHIBTY9 = ['782', '782']
# XMMRTY1 = ['783', '784']
# XMMRTY2 = ['785', '786']
# XMMRTY3 = ['787', '788']
# XMMRTY4 = ['789', '790']
# XMMRTY5 = ['791', '791']
# XMMRTY6 = ['792', '792']
# XMMRTY7 = ['793', '793']
# XMMRTY8 = ['794', '794']
# XMMRTY9 = ['795', '795']
# XPCVTY1 = ['796', '797']
# XPCVTY2 = ['798', '799']
# XPCVTY3 = ['800', '801']
# XPCVTY4 = ['802', '803']
# XPCVTY5 = ['804', '805']
# XPCVTY6 = ['806', '807']
# XPCVTY7 = ['808', '809']
# XPCVTY8 = ['810', '810']
# XPCVTY9 = ['811', '811']
# XPOLTY1 = ['812', '813']
# XPOLTY2 = ['814', '815']
# XPOLTY3 = ['816', '817']
# XPOLTY4 = ['818', '819']
# XPOLTY5 = ['820', '821']
# XPOLTY6 = ['822', '823']
# XPOLTY7 = ['824', '824']
# XPOLTY8 = ['825', '825']
# XPOLTY9 = ['826', '826']
# XROTTY1 = ['827', '828']
# XROTTY2 = ['829', '830']
# XROTTY3 = ['831', '832']
# XROTTY4 = ['833', '834']
# XROTTY5 = ['835', '836']
# XROTTY6 = ['837', '837']
# XROTTY7 = ['838', '838']
# XROTTY8 = ['839', '839']
# XROTTY9 = ['840', '840']
# XVRCTY1 = ['841', '842']
# XVRCTY2 = ['843', '844']
# XVRCTY3 = ['845', '846']
# XVRCTY4 = ['847', '847']
# XVRCTY5 = ['848', '848']
# XVRCTY6 = ['849', '849']
# XVRCTY7 = ['850', '850']
# XVRCTY8 = ['851', '851']
# XVRCTY9 = ['852', '852']
# INS_1 = ['853', '854']
# INS_2 = ['855', '856']
# INS_3 = ['857', '858']
# INS_3A = ['859', '860']
# INS_4_5 = ['861', '862']
# INS_6 = ['863', '864']
# INS_11 = ['865', '866']

# %%
#This saves the dictionary to a csv file.

import pandas as pd

(pd.DataFrame.from_dict(data=NIS_dict1, orient='index')
    .to_csv('data_wk5/NIS_kv.csv', header=False))

# %%
#TEST of pandas reading a file with fixed width columns (pd.read_fwf)
NIS_testfwf = pd.read_fwf('data_wk5/nispuf14.dat', header=None, index_col=0)

# %%
NIS_testfwf.head()
# Out:
#                                                                                 1   \
# 0
# 000011000012    .                  .           ...  223365.2500152.1875182.6250..3
# 000021000021 806.84601169505000 806.84601169505...  222 91.3125121.7500 91.3125..6
# 000031000032    .                  .           ...  222152.1875152.1875 91.3125..6
# 000041000041  63.44868567610260  63.44868567610...  221334.8125182.6250273.9375..4
# 000051000051  94.87263225744540  94.87263225744...  223   .       .       .    ..8
#
#                                                        2   3   \
# 0
# 000011000012    .                  .           ...  2 131   2
# 000021000021 806.84601169505000 806.84601169505...  1 123   2
# 000031000032    .                  .           ...  1 143   1
# 000041000041  63.44868567610260  63.44868567610...  1 112   2
# 000051000051  94.87263225744540  94.87263225744...  3 243   1
#
#                                                                                                    4   \
# 0
# 000011000012    .                  .           ...  .4223.000000000000001142131299999912 12 222212...
# 000021000021 806.84601169505000 806.84601169505...  .2120.500000000000003 4.1211 . 2 212 21 363618...
# 000031000032    .                  .           ...  24111.7668979696736121221222 1 1 131 21 727215...
# 000041000041  63.44868567610260  63.44868567610...  .4123.0000000000000011421312 . 2 212 12 161642...
# 000051000051  94.87263225744540  94.87263225744...  12120.500000000000003 321212 1 3 312 21 737332...
#
#                                                      5    6        7  8   \
# 0
# 000011000012    .                  .           ...    .    .    .   .  .
# 000021000021 806.84601169505000 806.84601169505...   65  127  191 387  .
# 000031000032    .                  .           ...    .    .    .   .  .
# 000041000041  63.44868567610260  63.44868567610...   62   91  122 184  .
# 000051000051  94.87263225744540  94.87263225744...  119  224  308 844  .
#
#                                                       9            10 ...   \
# 0                                                                     ...
# 000011000012    .                  .           ...  ....    .   .   . ...
# 000021000021 806.84601169505000 806.84601169505...  ....  351 387 421 ...
# 000031000032    .                  .           ...  ....    .   .   . ...
# 000041000041  63.44868567610260  63.44868567610...  ....  184 217 553 ...
# 000051000051  94.87263225744540  94.87263225744...  ....  40410611099 ...
#
#                                                           80   81          82  \
# 0
# 000011000012    .                  .           ...       NaN  NaN         NaN
# 000021000021 806.84601169505000 806.84601169505...    D3D3HS   30  74747474.0
# 000031000032    .                  .           ...       NaN  NaN         NaN
# 000041000041  63.44868567610260  63.44868567610...  D3D3D3D3   30  74747474.0
# 000051000051  94.87263225744540  94.87263225744...  HSHSHSHS   VM    747474.0
#
#                                                           83      84   85  \
# 0
# 000011000012    .                  .           ...       NaN     NaN  NaN
# 000021000021 806.84601169505000 806.84601169505...    D3D308  RMRMRM  NaN
# 000031000032    .                  .           ...       NaN     NaN  NaN
# 000041000041  63.44868567610260  63.44868567610...  D3D3D3D3    RGRG   VO
# 000051000051  94.87263225744540  94.87263225744...    080821      RM   VM
#
#                                                        86 87 88   89
# 0
# 000011000012    .                  .           ...  . . .  .  .  . .
# 000021000021 806.84601169505000 806.84601169505...  2 . .  2  2  2 .
# 000031000032    .                  .           ...  . . .  .  .  . .
# 000041000041  63.44868567610260  63.44868567610...  1 2 2  .  2  2 2
# 000051000051  94.87263225744540  94.87263225744...  2 1 1  .  2  277
#
# [5 rows x 89 columns]

# %% [markdown]
# Very very interesting! It really does try to read the format of the first 100 rows to determin where the fixed width columns are in the file. Unfortionately, the .dat dile is not a good example for this function at the moment. For future reference here is the read_fwf documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_fwf.html#pandas.read_fwf

# %% [markdown]
# Here is the TIP from the week 5 assignment (with my revisions):
#
# NIS_dataline = []
#
# for line in NIS_dict1:
#     create a dictionary with Variable Name as key,
#     use Begin / End numbers as a slice to give the dictionary's value
#     append dictionary to data_line
# write data_line to CSV file

# %% [markdown]
# This is another code hint:
# Outer loop reads lines from data file:
#     Inner loop applies each of the key/value pairs to the line
#     Append each result to a dictionary, or string, etc.
# Write dictionary/string to CSV or JSON file
#
# #TRY import csv??
#
# NIS_lines = []
# with open('data_wk5/nispuf14.dat') as data_file:
#     for line in data_file:
#         for key, value in NIS_dict1.items():
#             keys = line[value]
#             NIS_lines.append(line.strip())
#             print(key, value)

# %% [markdown]
# The above didn't quite work for me, so moving on I reached out for more help to get me out of this rut....

# %%
#Let's go back to make sure our dataframe is still there
NIS_dfclean.shape
# Out:
# (462, 3)

# %%
#Take a look at the data frame columns
NIS_dfclean.columns
# Out:
# Index(['Variable Name', 'Begin', 'End'], dtype='object')

# %%
#Here we will convert the Begin column to an integer using to_numeric.
import pandas as pd
pd.to_numeric(NIS_dfclean['Begin'], errors='coerced', downcast='signed')
# Out:
# 0        1.0
# 1        7.0
# 2       12.0
# 3       13.0
# 5       32.0
# 7       51.0
# 9       70.0
# 11      89.0
# 12      93.0
# 13      97.0
# 14      98.0
# 15     100.0
# 16     101.0
# 17     102.0
# 18     110.0
# 20     118.0
# 21     126.0
# 23     127.0
# 25     128.0
# 26     129.0
# 27     131.0
# 28     133.0
# 29     134.0
# 30     135.0
# 31     137.0
# 32     139.0
# 33     140.0
# 34     141.0
# 35     142.0
# 36     158.0
#        ...
# 675    820.0
# 676    822.0
# 677    824.0
# 678    825.0
# 679    826.0
# 680    827.0
# 681    829.0
# 682    831.0
# 683    833.0
# 684    835.0
# 685    837.0
# 686    838.0
# 687    839.0
# 688    840.0
# 689    841.0
# 690    843.0
# 691    845.0
# 692    847.0
# 693    848.0
# 694    849.0
# 696    850.0
# 697    851.0
# 698    852.0
# 699    853.0
# 701    855.0
# 702    857.0
# 703    859.0
# 704    861.0
# 706    863.0
# 708    865.0
# Name: Begin, Length: 462, dtype: float64

# %%
#Here we will do the same to convert the End column to an integer using to_numeric.
pd.to_numeric(NIS_dfclean['End'], errors='coerce', downcast='signed')
# Out:
# 0        6.0
# 1       11.0
# 2       12.0
# 3       31.0
# 5       50.0
# 7       69.0
# 9       88.0
# 11      92.0
# 12      96.0
# 13      97.0
# 14      99.0
# 15     100.0
# 16     101.0
# 17     109.0
# 18     117.0
# 20     125.0
# 21     126.0
# 23     127.0
# 25     128.0
# 26     130.0
# 27     132.0
# 28     133.0
# 29     134.0
# 30     136.0
# 31     138.0
# 32     139.0
# 33     140.0
# 34     141.0
# 35     157.0
# 36     158.0
#        ...
# 675    821.0
# 676    823.0
# 677    824.0
# 678    825.0
# 679    826.0
# 680    828.0
# 681    830.0
# 682    832.0
# 683    834.0
# 684    836.0
# 685    837.0
# 686    838.0
# 687    839.0
# 688    840.0
# 689    842.0
# 690    844.0
# 691    846.0
# 692    847.0
# 693    848.0
# 694    849.0
# 696    850.0
# 697    851.0
# 698    852.0
# 699    854.0
# 701    856.0
# 702    858.0
# 703    860.0
# 704    862.0
# 706    864.0
# 708    866.0
# Name: End, Length: 462, dtype: float64

# %% [markdown]
# Oddly enough, it changed both columns 'Begin' and 'End' to a float? Not an integer. Even though downcast is applied to integer it still doesn't work. Let's move on to see what we can do further...

# %%
#Just looking at the head of the dataframe again....
NIS_dfclean.head()
# Out:
#    Variable Name Begin End
# 0        SEQNUMC     1   6
# 1       SEQNUMHH     7  11
# 2           PDAT    12  12
# 3       PROVWT_D    13  31
# 5  PROVWT_D_TERR    32  50

# %%
data_rows = []
with open('data_wk5/nispuf14.dat') as infile:    
    for line in infile:
        data_dict = {}      # new, empty dictionary for each line
        for row in NIS_dfclean.itertuples():
            start = int(row[0])
            end = int(row[0])
            data_dict[row[1]] = line[start : end]
            data_rows.append(data_dict)

# %%
len(data_rows)
# Out:
# 11502414

# %%
import csv

with open('data_wk5/nispuf14.csv', 'w') as outfile:
    writer = csv.DictWriter(outfile, data_rows[0].keys())
    writer.writeheader()
    for row in data_rows:
        writer.writerow(row)

# %% [markdown]
# In conclusion, I was able to get my hands dirty and experience some complicated data sets. All in all, I was able to create a csv file from the complicated data set after cleaning it. This allows us to deal with the data in a cleaner state and as a csv file.
